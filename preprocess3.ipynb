# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import warnings
import re
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, roc_auc_score, classification_report
import xgboost as xgb

# 경고 메시지 끄기 (깔끔한 출력을 위해)
warnings.filterwarnings('ignore')

# %% [markdown]
# # 데이터 로드

# %%
train_path = r"..\datasets\train.csv"
test_path  = r"..\datasets\test.csv"

try:
    train = pd.read_csv(train_path)
    test = pd.read_csv(test_path)
    print(f"학습 세트: {train.shape}")
    print(f"테스트 세트: {test.shape}")
except FileNotFoundError:
    print("❌ 파일을 찾을 수 없습니다. 경로를 확인해주세요.")
# Out:
# 학습 세트: (748, 46)
# 테스트 세트: (814, 45)

# %% [markdown]
# # 데이터 통합

# %% [markdown]
# 정석은 학습 세트와 테스트 세트를 먼저 분할한 후 전처리를 진행하지만,
#
# 단순 모델의 성능을 올리기 위해 학습 세트와 테스트 세트 데이터를 합쳐서 한꺼번에 전처리 후 분할하는 방식 시도

# %%
# 나중에 분리하기 위해 꼬리표(Label) 붙이기
train['dataset'] = 'train'
test['dataset'] = 'test'

# 위아래로 합치기
df_all = pd.concat([train, test], ignore_index=True)

print(f"합쳐진 데이터 크기: {df_all.shape}\n")
# 잘 합쳐졌는지 확인
print(df_all['dataset'].value_counts())
# Out:
# 합쳐진 데이터 크기: (1562, 47)
#
# dataset
# test     814
# train    748
# Name: count, dtype: int64

# %%
# =========================================================
# [중간 점검] 현재 데이터프레임의 결측치 현황 확인
# =========================================================

print("\n" + "=" * 60)
print("🔍 결측치(NaN) 보유 컬럼 및 개수 확인")
print("=" * 60)

# 1. 컬럼별 결측치 개수 계산
null_counts = df_all.isnull().sum()

# 2. 결측치가 1개라도 있는 컬럼만 필터링
null_cols = null_counts[null_counts > 0].sort_values(ascending=False)

if len(null_cols) > 0:
    print(f"⚠️ 총 {len(null_cols)}개 컬럼에서 결측치가 발견되었습니다.")
    print("-" * 60)
    print(f"{'컬럼명':<30} | {'결측치 개수':<10} | {'비율(%)'}")
    print("-" * 60)
    
    for col_name, count in null_cols.items():
        ratio = (count / len(df_all)) * 100
        print(f"{col_name:<30} | {count:<10} | {ratio:.2f}%")
else:
    print("✅ 현재 데이터프레임에 결측치가 하나도 없습니다! (Clean)")

print("=" * 60 + "\n")
# Out:
# ============================================================
# 🔍 결측치(NaN) 보유 컬럼 및 개수 확인
# ============================================================
# ⚠️ 총 19개 컬럼에서 결측치가 발견되었습니다.
# ------------------------------------------------------------
# 컬럼명                            | 결측치 개수     | 비율(%)
# ------------------------------------------------------------
# contest_award                  | 1562       | 100.00%
# idea_contest                   | 1562       | 100.00%
# contest_participation          | 1556       | 99.62%
# class4                         | 1554       | 99.49%
# class3                         | 1502       | 96.16%
# previous_class_6               | 1261       | 80.73%
# previous_class_7               | 1261       | 80.73%
# previous_class_8               | 1261       | 80.73%
# previous_class_4               | 1261       | 80.73%
# previous_class_5               | 1261       | 80.73%
# previous_class_3               | 1261       | 80.73%
# class2                         | 1151       | 73.69%
# completed                      | 814        | 52.11%
# major1_2                       | 622        | 39.82%
# completed_semester             | 102        | 6.53%
# major_field                    | 97         | 6.21%
# major type                     | 96         | 6.15%
# major1_1                       | 93         | 5.95%
# nationality                    | 1          | 0.06%
# ============================================================

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# 분석 대상 변수 리스트
target_features = [
    'previous_class_3', 'previous_class_4', 'previous_class_5', 
    'previous_class_6', 'previous_class_7', 'previous_class_8'
]

print("\n" + "=" * 70)
print("🔍 [긴급 진단] previous_class 6형제 중요도 & 상관관계 분석")
print("=" * 70)

# 1. 분석을 위한 임시 데이터셋 준비 (Train 데이터만 사용!)
# Test 데이터는 정답(completed)이 없으므로 분석 불가
temp_df = df_all[df_all['dataset'] == 'train'].copy()

# 2. 간단 전처리 (결측치 채우기 + 문자열로 변환)
for col in target_features:
    if col in temp_df.columns:
        temp_df[col] = temp_df[col].fillna('Unknown').astype(str)
    else:
        print(f"⚠️ {col} 컬럼이 없습니다.")

# 3. 인코딩 (Random Forest용 레이블 인코딩)
# 다중선택 텍스트라도 일단 하나의 카테고리로 보고 숫자로 바꿈 (간이 분석용)
le = LabelEncoder()
encoded_features = []

for col in target_features:
    if col in temp_df.columns:
        # 인코딩된 컬럼명 생성
        new_col = f"{col}_enc"
        temp_df[new_col] = le.fit_transform(temp_df[col])
        encoded_features.append(new_col)

# ---------------------------------------------------------
# A. 상관계수 (Correlation) 분석
# ---------------------------------------------------------
print("\n📊 1) Target(completed)과의 상관계수 (절댓값 순)")
print("-" * 50)

# 상관계수 계산
corr_matrix = temp_df[encoded_features + ['completed']].corr()
target_corr = corr_matrix['completed'].drop('completed') # 자기 자신 제외

# 절댓값 기준으로 정렬해서 출력
print(target_corr.abs().sort_values(ascending=False))


# ---------------------------------------------------------
# B. 변수 중요도 (Feature Importance) - Random Forest
# ---------------------------------------------------------
print("\n🌲 2) Random Forest 변수 중요도 (Gini Importance)")
print("-" * 50)

# 모델 학습 (가볍게 100그루만)
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
X = temp_df[encoded_features]
y = temp_df['completed']

rf.fit(X, y)

# 중요도 추출
importances = pd.Series(rf.feature_importances_, index=target_features)
sorted_importances = importances.sort_values(ascending=False)

print(sorted_importances)

# (선택) 시각화가 필요하면 주석 해제
plt.figure(figsize=(10, 6))
sns.barplot(x=sorted_importances.values, y=sorted_importances.index)
plt.title('Previous Class Feature Importance')
plt.show()

print("=" * 70 + "\n")
# Out:
# ======================================================================
# 🔍 [긴급 진단] previous_class 6형제 중요도 & 상관관계 분석
# ======================================================================
#
# 📊 1) Target(completed)과의 상관계수 (절댓값 순)
# --------------------------------------------------
# previous_class_3_enc    0.129775
# previous_class_4_enc    0.091563
# previous_class_8_enc    0.074715
# previous_class_5_enc    0.040367
# previous_class_7_enc    0.034480
# previous_class_6_enc    0.009579
# Name: completed, dtype: float64
#
# 🌲 2) Random Forest 변수 중요도 (Gini Importance)
# --------------------------------------------------
# previous_class_8    0.401269
# previous_class_7    0.233743
# previous_class_6    0.169646
# previous_class_5    0.085640
# previous_class_4    0.057135
# previous_class_3    0.052566
# dtype: float64
# ======================================================================

# %% [markdown]
# # 데이터 전처리 - 변수 제거(1)

# %% [markdown]
# 1. 수동 제거<br>
# [ID] -> 고유 식별자<br>
# [generation], [nationality] -> 상수<br>
# [interested_company], [incumbents_lecture_scale_reason] -> 서술형
#
# 2. 결측치 개수가 전체 데이터의 80% 이상인 8개의 피처 제거<br>
# [previous_class_6], [previous_class_7], [previous_class_8]는 결측치가 80% 이상이지만 변수 중요도 평가에서 유의미하다고 판단하여 제거하지 않음.

# %%
# =========================================================
# 데이터 전처리 - 변수 제거 (수정됨)
# =========================================================

# 1. 수동으로 지정한 삭제 컬럼 (5개)  
manual_drop_cols = ['ID', 'generation', 'nationality', 'interested_company', 'incumbents_lecture_scale_reason']

# 2. 결측치가 80% 이상인 컬럼 자동 찾기 (기준 완화: 0.5 -> 0.8)
missing_rate = df_all.isnull().mean()
high_missing_cols = missing_rate[missing_rate >= 0.8].index.tolist()

# 3. 보호해야 할 컬럼 설정 (삭제 면제 리스트)
# - 기본 보호: 타겟변수(completed), 데이터구분(dataset)
# - 추가 보호: 결측이 많아도 중요도가 높았던 변수들(previous_class 시리즈)
protect_cols = [
    'completed', 'dataset', 
    'previous_class_6', 'previous_class_7', 'previous_class_8'
]

# 실제로 자동 삭제될 리스트 (보호 대상 제외)
real_high_missing_cols = [c for c in high_missing_cols if c not in protect_cols]

# 4. 삭제 대상 통합 (중복 제거)
# 수동 삭제 대상과 자동 삭제 대상을 합침
final_remove_list = list(set(manual_drop_cols + real_high_missing_cols))

# 삭제 실행
df_all = df_all.drop(columns=final_remove_list)

# 결과 출력
print(f"🗑️ [수동 삭제] 지정된 5개 변수:") 
print(f"   -> {manual_drop_cols}")
print("-" * 50)
print(f"🗑️ [자동 삭제] 결측치 80% 이상 (보호변수 제외 총 8개):")
print(f"   -> {sorted(real_high_missing_cols)}")
print("-" * 50)
print(f"🛡️ [보호됨] 결측치 80% 이상이지만 삭제되지 않은 변수:")
# 80% 이상인데 보호 목록에 있어서 살아남은 애들만 출력
saved_cols = [c for c in high_missing_cols if c in protect_cols]
print(f"   -> {saved_cols}")
print("-" * 50)
print(f"✅ 총 삭제된 컬럼 수: {len(final_remove_list)}개")
print(f"📊 현재 남은 컬럼 수: {df_all.shape[1]}")
# Out:
# 🗑️ [수동 삭제] 지정된 5개 변수:
#    -> ['ID', 'generation', 'nationality', 'interested_company', 'incumbents_lecture_scale_reason']
# --------------------------------------------------
# 🗑️ [자동 삭제] 결측치 80% 이상 (보호변수 제외 총 8개):
#    -> ['class3', 'class4', 'contest_award', 'contest_participation', 'idea_contest', 'previous_class_3', 'previous_class_4', 'previous_class_5']
# --------------------------------------------------
# 🛡️ [보호됨] 결측치 80% 이상이지만 삭제되지 않은 변수:
#    -> ['previous_class_6', 'previous_class_7', 'previous_class_8']
# --------------------------------------------------
# ✅ 총 삭제된 컬럼 수: 13개
# 📊 현재 남은 컬럼 수: 34

# %% [markdown]
# # 데이터 전처리 - 결측치/이상치 처리(2)

# %% [markdown]
# 수치형 변수 결측치/이상치 처리
#
# [completed_semester]
#
# -> 중앙값으로 대체 후 데이터 타입을 연속형에서 정수형으로 변환.
#
# 값이 0인 데이터가 하나 있었지만, ‘job’==‘직장인’, ‘major1_1’==‘기타’, ‘school1’==0인 것으로 보아, 대학 진학없이 바로 취직한 특이 케이스로 간주하여 이상치 처리 X

# %%
target_col = 'completed_semester'

# 1. 이상치 확인 (20 이상인 값들 미리 보기)
outlier_mask = df_all[target_col] >= 20
outliers = df_all.loc[outlier_mask, target_col].tolist()

print(f"🔍 [확인] 값이 20 이상인 이상치 목록 ({len(outliers)}개):")
print(f"   -> {outliers}")

# 2. 이상치 처리: NaN으로 변경 (그래야 중앙값 계산 등에서 제외됨)
# (0인 값은 정상 데이터이므로 건드리지 않음)
df_all.loc[outlier_mask, target_col] = np.nan

# 3. 중앙값 계산 (학습용 데이터 기준!)
median_val = df_all.loc[df_all['dataset'] == 'train', target_col].median()

# 4. 결측치(NaN)를 중앙값으로 채우기 & 정수 변환
df_all[target_col] = df_all[target_col].fillna(median_val).astype(int)

print("-" * 50)
print(f"✅ '{target_col}' 결측치 및 이상치 처리 완료")
print(f"   - 대체된 중앙값: {median_val}\n")
print(df_all[target_col].describe())
# Out:
# 🔍 [확인] 값이 20 이상인 이상치 목록 (3개):
#    -> [2020.02, 20241.0, 20241.0]
# --------------------------------------------------
# ✅ 'completed_semester' 결측치 및 이상치 처리 완료
#    - 대체된 중앙값: 6.0
#
# count    1562.000000
# mean        6.117157
# std         1.742479
# min         0.000000
# 25%         5.000000
# 50%         6.000000
# 75%         8.000000
# max        10.000000
# Name: completed_semester, dtype: float64

# %% [markdown]
# 범주형 변수 결측치/이상치 처리
#
# [major type]에서 '단일 전공공학 (컴퓨터 공학 제외)'라는 이상치 발견

# %%
# 점검할 변수 리스트 (이진 변수 5인방)
check_targets = [
    'major type', 
    're_registration', 
    'project_type', 
    'incumbents_level', 
    'major_data'
]

print("🔍 [정밀 점검] 이진 변수 값 종류 확인")
print("=" * 60)

for col in check_targets:
    if col in df_all.columns:
        # 고유값 추출 (NaN 포함)
        uni_vals = df_all[col].unique()
        # 값 개수 카운트 (어떤 게 주류이고 어떤 게 이상치인지 파악용)
        val_counts = df_all[col].value_counts(dropna=False)
        
        print(f"📌 [{col}]")
        print(f"   - 고유값 목록 ({len(uni_vals)}개): {uni_vals}")
        print(f"   - 값 분포:\n{val_counts}")
        print("-" * 60)
    else:
        print(f"⚠️ {col} 컬럼이 존재하지 않습니다.")

print("점검 완료. 이상한 값이 보이면 매핑 딕셔너리에 추가하거나 전처리 단계에서 수정하세요.")
# Out:
# 🔍 [정밀 점검] 이진 변수 값 종류 확인
# ============================================================
# 📌 [major type]
#    - 고유값 목록 (4개): ['복수 전공 ( 다중전공, 이중전공 포함 )' '단일 전공' nan '단일 전공공학 (컴퓨터 공학 제외)']
#    - 값 분포:
# major type
# 단일 전공                      856
# 복수 전공 ( 다중전공, 이중전공 포함 )    609
# NaN                         96
# 단일 전공공학 (컴퓨터 공학 제외)          1
# Name: count, dtype: int64
# ------------------------------------------------------------
# 📌 [re_registration]
#    - 고유값 목록 (2개): ['아니요' '예']
#    - 값 분포:
# re_registration
# 아니요    1261
# 예       301
# Name: count, dtype: int64
# ------------------------------------------------------------
# 📌 [project_type]
#    - 고유값 목록 (2개): ['팀' '개인']
#    - 값 분포:
# project_type
# 팀     1103
# 개인     459
# Name: count, dtype: int64
# ------------------------------------------------------------
# 📌 [incumbents_level]
#    - 고유값 목록 (2개): ['시니어 (10년차 ~)' '주니어 (0~3년차)']
#    - 값 분포:
# incumbents_level
# 주니어 (0~3년차)     1074
# 시니어 (10년차 ~)     488
# Name: count, dtype: int64
# ------------------------------------------------------------
# 📌 [major_data]
#    - 고유값 목록 (2개): [False  True]
#    - 값 분포:
# major_data
# False    908
# True     654
# Name: count, dtype: int64
# ------------------------------------------------------------
# 점검 완료. 이상한 값이 보이면 매핑 딕셔너리에 추가하거나 전처리 단계에서 수정하세요.

# %% [markdown]
# [major1_1] → ‘Unknown’으로 대체
#
# [major type] → major1_1, major1_2 값이 둘 다 존재한다면 '복수 전공 ( 다중전공, 이중전공 포함 )', 그렇지 않다면 '단일 전공'으로 대체
#
# '단일 전공공학 (컴퓨터 공학 제외)' 이상치를 '단일 전공'으로 대체
#
# [major_field] → ‘Unknown’으로 대체
#
# [major1_2] → ‘없음’으로 대체

# %%
# 처리할 범주형 변수들
cat_cols = ['major1_1', 'major1_2', 'major_field', 'major type']

print("📊 [처리 전] 범주형 변수 결측치 개수:")
print(df_all[cat_cols].isnull().sum())


# ---------------------------------------------------------
# (0) [추가] 이상치 선제적 처리 (Cleaning)
# ---------------------------------------------------------
# 이상한 값('단일 전공공학...')을 미리 '단일 전공'으로 고쳐놓습니다.
# 이렇게 하면 아래 함수나 나중에 인코딩할 때 별도 예외처리가 필요 없습니다.
dirty_val = '단일 전공공학 (컴퓨터 공학 제외)'
if dirty_val in df_all['major type'].values:
    df_all['major type'] = df_all['major type'].replace(dirty_val, '단일 전공')
    print(f"✅ 이상치 수정 완료: '{dirty_val}' -> '단일 전공'")


# ---------------------------------------------------------
# (1) major1_1 & major_field: 단순 결측 채우기
# ---------------------------------------------------------
df_all['major1_1'] = df_all['major1_1'].fillna('Unknown')
df_all['major_field'] = df_all['major_field'].fillna('Unknown')


# ---------------------------------------------------------
# (2) major type: 결측치만 채우기 (기존 값 유지!)
# ---------------------------------------------------------
# 이미 값이 있으면 그대로 두고, 비어있는 경우에만 로직 적용
def fill_major_type(row):
    # 이미 값이 있으면 건드리지 않음 (아까 고친 '단일 전공'도 여기서 걸러져서 그대로 유지됨)
    if pd.notna(row['major type']):
        return row['major type']
    
    # 값이 비어있을 때만 추론:
    # major1_2가 있으면(값이 있고 '없음'이 아니면) -> 복수 전공으로 추정
    if pd.notna(row['major1_2']) and row['major1_2'] != '없음':
        return '복수 전공 ( 다중전공, 이중전공 포함 )' # (원래 값 유지)
    else:
        return '단일 전공'

df_all['major type'] = df_all.apply(fill_major_type, axis=1)


# ---------------------------------------------------------
# (3) major1_2: 마지막으로 채우기
# ---------------------------------------------------------
# 위에서 major type 채울 때 major1_2 값을 참고했으므로, 이제 안전하게 '없음'으로 채움
df_all['major1_2'] = df_all['major1_2'].fillna('없음')


print("-" * 50)
print("✅ [처리 후] 범주형 변수 결측치 개수:")
print(df_all[cat_cols].isnull().sum())
# Out:
# 📊 [처리 전] 범주형 변수 결측치 개수:
# major1_1        93
# major1_2       622
# major_field     97
# major type      96
# dtype: int64
# ✅ 이상치 수정 완료: '단일 전공공학 (컴퓨터 공학 제외)' -> '단일 전공'
# --------------------------------------------------
# ✅ [처리 후] 범주형 변수 결측치 개수:
# major1_1       0
# major1_2       0
# major_field    0
# major type     0
# dtype: int64

# %% [markdown]
# # 데이터 전처리 - 범주형 변수 인코딩(3)

# %% [markdown]
# [major type], [re_registration], [project_type], [major_data], [incumbents_level]
#
# -> 이진값(카테고리가 2개)을 가지는 5개의 변수: 레이블 인코딩

# %%
# ---------------------------------------------------------
# 이진 변수(Binary) 레이블 인코딩
# ---------------------------------------------------------

binary_mappings = {
    'major type': {
        '단일 전공': 0, 
        '복수 전공 ( 다중전공, 이중전공 포함 )': 1
    },
    're_registration': {'아니요': 0, '예': 1},
    'project_type': {'개인': 0, '팀': 1},
    'incumbents_level': {'주니어 (0~3년차)': 0, '시니어 (10년차 ~)': 1}
}

cols_to_map = ['major type', 're_registration', 'project_type', 'incumbents_level']

for col in cols_to_map:
    # 1. 매핑 전에 딕셔너리에 없는 이상한 값이 있는지 체크
    unique_vals = df_all[col].unique()
    valid_keys = binary_mappings[col].keys()
    
    # 딕셔너리에 없는 값 확인
    unknown_vals = [x for x in unique_vals if x not in valid_keys]
    
    if len(unknown_vals) > 0:
        print(f"🚨 {col}에서 매핑 규칙에 없는 값 발견: {unknown_vals}")
    
    # 2. 매핑 적용
    df_all[col] = df_all[col].map(binary_mappings[col])
    
    # 3. 결측치 안전 처리 (정수 변환)
    if df_all[col].isnull().sum() > 0:
        print(f"⚠️ {col}에 NaN 발생 -> 0으로 채움")
        df_all[col] = df_all[col].fillna(0).astype(int)
    
    # 4. 타입 확실하게 정수로 변환 (위에서 NaN 없을 때도 int로 만들기 위함)
    df_all[col] = df_all[col].astype(int)

print("✅ 레이블 인코딩 완료")


# ---------------------------------------------------------
# major_data (Boolean) 처리
# ---------------------------------------------------------
if 'major_data' in df_all.columns:
    df_all['major_data'] = df_all['major_data'].astype(int)

print("-" * 50)
# 확인 대상에 major_data 포함
check_cols = cols_to_map + ['major_data']
print(df_all[check_cols].head())
# Out:
# ✅ 레이블 인코딩 완료
# --------------------------------------------------
#    major type  re_registration  project_type  incumbents_level  major_data
# 0           1                0             1                 1           0
# 1           1                0             1                 0           1
# 2           0                0             0                 0           0
# 3           1                0             1                 0           0
# 4           1                0             1                 0           1

# %% [markdown]
# 희소 카테고리 통합 필요없는 변수들부터 인코딩
#
# 1. 일반 명목형 변수
#
# [class1], [job], [hope_for_group], [desired_career_path], [incumbents_lecture_type]
#
# 2. 다중 선택 가능 변수
#
# [desired_job_except_data], [expected_domain]

# %%
# ---------------------------------------------------------
# 1. 사전 전처리 (콤마 및 패턴 수정)
# ---------------------------------------------------------

# (1) expected_domain 복구 (기존 로직 유지)
domain_fix_map = {
    'M. 전문, 과학 및 기술 서비스업': 'M. 전문 과학 및 기술 서비스업',
    'R. 예술, 스포츠 및 여가관련 서비스업': 'R. 예술 스포츠 및 여가관련 서비스업',
    'O. 공공 행정, 국방 및 사회보장 행정': 'O. 공공 행정 국방 및 사회보장 행정',
    'N. 사업시설 관리, 사업 지원 및 임대 서비스업': 'N. 사업시설 관리 사업 지원 및 임대 서비스업',
    'S. 협회 및 단체, 수리 및 기타 개인 서비스업': 'S. 협회 및 단체 수리 및 기타 개인 서비스업',
    'D. 전기, 가스, 증기 및 공기 조절 공급업': 'D. 전기 가스 증기 및 공기 조절 공급업', 
    'E. 수도, 하수 및 폐기물 처리, 원료 재생업': 'E. 수도 하수 및 폐기물 처리 원료 재생업',
    'A. 농업, 임업 및 어업': 'A. 농업 임업 및 어업',
    'T. 가구 내 고용활동 및 달리 분류되지 않은 자가 소비 생산활동': 'T. 가구 내 고용활동'
}
if 'expected_domain' in df_all.columns:
    for dirty, clean in domain_fix_map.items():
        df_all['expected_domain'] = df_all['expected_domain'].astype(str).str.replace(dirty, clean, regex=False)

# (2) incumbents_lecture_type 문제 해결 (온, 오프라인 -> 온_오프라인)
# 콤마 때문에 찢어지는 걸 방지하기 위해 콤마를 언더바(_)나 슬래시(/)로 변경
if 'incumbents_lecture_type' in df_all.columns:
    df_all['incumbents_lecture_type'] = df_all['incumbents_lecture_type'].str.replace('온, 오프라인', '온_오프라인', regex=False)


# ---------------------------------------------------------
# 2. 인코딩 실행 (공백 트림 기능 추가)
# ---------------------------------------------------------
target_cols = [
    'class1', 'job', 'hope_for_group', 'desired_career_path', 'incumbents_lecture_type', 
    'desired_job_except_data', 'expected_domain'
]

print(f"🚀 인코딩 시작 (대상 {len(target_cols)}개)")
print("=" * 60)

for col in target_cols:
    if col not in df_all.columns: continue

    # (핵심) 콤마 기준으로 찢되, 앞뒤 공백을 제거(strip)하면서 찢어야 함
    # str.get_dummies는 strip 옵션이 없으므로, 수동으로 구현해야 함
    
    # 1. 콤마로 쪼개고(split) -> 공백 제거(strip) -> 다시 합치기(join)
    # 이렇게 하면 "A, B" -> "A,B"로 정리가 됨
    def clean_comma_sep(text):
        if pd.isna(text): return text
        # 콤마로 쪼개서 각각 strip() 하고 다시 콤마로 합침
        return ','.join([x.strip() for x in text.split(',')])
    
    temp_series = df_all[col].astype(str).apply(clean_comma_sep)
    
    # 2. 이제 깨끗해진 상태에서 get_dummies 실행 (★ 수정: dtype=int)
    dummies = temp_series.str.get_dummies(sep=',').astype(int)
    
    dummies = dummies.add_prefix(f"{col}_")
    new_cols = dummies.columns.tolist()
    
    df_all = pd.concat([df_all, dummies], axis=1)
    df_all.drop(columns=[col], inplace=True)
    
    print(f"📌 [{col}] -> {len(new_cols)}개 생성")
    print(f"   - 변수명: {new_cols}")
    print("-" * 60)

print(f"🎉 최종 컬럼 수: {df_all.shape[1]}")
# Out:
# 🚀 인코딩 시작 (대상 7개)
# ============================================================
# 📌 [class1] -> 13개 생성
#    - 변수명: ['class1_1', 'class1_11', 'class1_12', 'class1_13', 'class1_14', 'class1_15', 'class1_16', 'class1_2', 'class1_4', 'class1_5', 'class1_6', 'class1_7', 'class1_8']
# ------------------------------------------------------------
# 📌 [job] -> 4개 생성
#    - 변수명: ['job_대학생', 'job_대학원생', 'job_직장인', 'job_취준생']
# ------------------------------------------------------------
# 📌 [hope_for_group] -> 3개 생성
#    - 변수명: ['hope_for_group_네. 오프라인으로 참여하고 싶어요', 'hope_for_group_네. 온라인으로 참여하고 싶어요', 'hope_for_group_아니요. 개인적으로 학회 활동을 하고 싶어요']
# ------------------------------------------------------------
# 📌 [desired_career_path] -> 5개 생성
#    - 변수명: ['desired_career_path_대학원 진학', 'desired_career_path_이직', 'desired_career_path_창업', 'desired_career_path_취업', 'desired_career_path_현재 직장 유지']
# ------------------------------------------------------------
# 📌 [incumbents_lecture_type] -> 3개 생성
#    - 변수명: ['incumbents_lecture_type_오프라인', 'incumbents_lecture_type_온_오프라인 동시', 'incumbents_lecture_type_온라인']
# ------------------------------------------------------------
# 📌 [desired_job_except_data] -> 8개 생성
#    - 변수명: ['desired_job_except_data_A. 금융 / 보험 직무', 'desired_job_except_data_B. 기획 / 전략 / 경영 직무', 'desired_job_except_data_C. MD', 'desired_job_except_data_D. 소프트웨어 개발자', 'desired_job_except_data_E. UI/UX 디자이너', 'desired_job_except_data_F. PM / 서비스 기획자', 'desired_job_except_data_G. 자연과학계열 연구자', 'desired_job_except_data_H. 마케터 / 영업관리']
# ------------------------------------------------------------
# 📌 [expected_domain] -> 20개 생성
#    - 변수명: ['expected_domain_A. 농업 임업 및 어업', 'expected_domain_C. 제조업', 'expected_domain_D. 전기 가스 증기 및 공기 조절 공급업', 'expected_domain_E. 수도 하수 및 폐기물 처리 원료 재생업', 'expected_domain_F. 건설업', 'expected_domain_G. 도매 및 소매업', 'expected_domain_H. 운수 및 창고업', 'expected_domain_I. 숙박 및 음식점업', 'expected_domain_J. 정보통신업', 'expected_domain_K. 금융 및 보험업', 'expected_domain_L. 부동산업', 'expected_domain_M. 전문 과학 및 기술 서비스업', 'expected_domain_N. 사업시설 관리 사업 지원 및 임대 서비스업', 'expected_domain_O. 공공 행정 국방 및 사회보장 행정', 'expected_domain_P. 교육 서비스업', 'expected_domain_Q. 보건업 및 사회복지 서비스업', 'expected_domain_R. 예술 스포츠 및 여가관련 서비스업', 'expected_domain_S. 협회 및 단체 수리 및 기타 개인 서비스업', 'expected_domain_T. 가구 내 고용활동', 'expected_domain_U. 국제 및 외국기관']
# ------------------------------------------------------------
# 🎉 최종 컬럼 수: 83

# %% [markdown]
# 희소 카테고리 통합이 필요한 변수들 인코딩
#
# 1. 일반 명목형 변수: 데이터 수가 5 이하인 카테고리를 모두 '희소'로 통합
#
# [what_to_gain], [incumbents_lecture], [incumbents_company_level], [inflow_route], [incumbents_lecture_scale], [whyBDA]

# %%
# 점검 대상 (희소 통합 예정 변수들)
check_targets = [
    'what_to_gain', 
    'incumbents_lecture', 
    'incumbents_company_level', 
    'inflow_route', 
    'incumbents_lecture_scale', 
    'whyBDA'
]

print("🔍 [사전 점검] 희소 통합 대상 변수 현황")
print("=" * 60)
pd.set_option('display.max_rows', None)

for col in check_targets:
    if col in df_all.columns:
        print(f"📌 [{col}]")
        
        # 빈도수 확인
        val_counts = df_all[col].value_counts(dropna=False)
        
        print(f"   - 총 카테고리 종류: {len(val_counts)}개")
        print("-" * 30)
        print(val_counts)
        
        # 5개 이하인 것들이 몇 개나 되는지 미리 계산해서 보여줌
        rare_cnt = (val_counts <= 5).sum()
        print("-" * 30)
        print(f"⚠️ [알림] 5개 이하 희소 카테고리: {rare_cnt}개 (통합 대상)")
        print("=" * 60)
        
    else:
        print(f"⚠️ {col} 컬럼이 존재하지 않습니다.")

pd.reset_option('display.max_rows')
# Out:
# 🔍 [사전 점검] 희소 통합 대상 변수 현황
# ============================================================
# 📌 [what_to_gain]
#    - 총 카테고리 종류: 12개
# ------------------------------
# what_to_gain
# 데이터 분석 역량                                                                          994
# 프로젝트 경험                                                                            347
# 공모전 경험                                                                             152
# 인적 네트워크                                                                             61
# 기초적인 python, sql 지식 숙지                                                               1
# 위 항목 전체                                                                              1
# 공모전과 프로젝트                                                                            1
# 사실 한가지를 고르기 어렵습니다..ㅠㅠ 학회를 통해 위의 4가지와 협업에 계신 전문가님들에게 유익한 정보를 얻고 소중한 경험을 하고 싶습니다.      1
# 분석 역량, 공모전 경험, 인적 네트워크                                                               1
# 개인적으로는 데이터 분석 역량을 키우고, 인적 네트워크를 다져 프로젝트 등 경험과 실적을 쌓을 수 있는 힘을 기르고 또 그렇게 하기 위함         1
# 취업팁                                                                                  1
# 위 모두 ..!                                                                             1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 카테고리: 8개 (통합 대상)
# ============================================================
# 📌 [incumbents_lecture]
#    - 총 카테고리 종류: 11개
# ------------------------------
# incumbents_lecture
# 커리어 패스 과정 (예시: 비전공자/전공자의 취업 준비 및 이직 과정)    788
# 직무 강의 (예시: 실무 진행 방식 및 직무 준비생을 위한 팁)        609
# 산업 트렌드 (예시: ChatGPT로 인한 직무 변화)             157
# 커리어 패스 과정과 직무 강의 둘다 궁금합니다                    1
# 원동력                                          1
# 위 항목 전부 다                                    1
# 위에 3가지 모두 듣고 싶습니다                            1
# 위 3개 전부 다                                    1
# 취업하기 위해 준비했던 각종 데이터 관련 경험들                   1
# 커리어패스, 산업 트렌드                                1
# 커리어 패스 과정과 직무 강의를 듣고 싶습니다                    1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 카테고리: 8개 (통합 대상)
# ============================================================
# 📌 [incumbents_company_level]
#    - 총 카테고리 종류: 26개
# ------------------------------
# incumbents_company_level
# 국내 대기업 IT 계열 (금융, 제조 ...)               619
# 국내 빅테크 IT 계열 (네카라쿠배당토)                  585
# 해외 기업 (빅테크)                             245
# 스타트업 C-level                             91
# 국내와 해외 기업 현직자 모두에게 들었으면 좋겠다.              1
# 배터리 관련 기업                                 1
# 바이오인공지능 계열                                1
# 국내외 반도체 기업                                1
# 은행 및 보험 쪽 IT                              1
# 잘 모르겠음                                    1
# 국내 대기업 IT 계열과 해외 기업 현직자에게 가장 듣고 싶습니다      1
# 국내 빅테크 IT계열, 해외 기업 둘 다                    1
# ...                                       1
# 공간정보 관련 직무 계열                             1
# 1순위: 국내 대기업 IT 계열. 2순위: 해외 기업(빅테크)        1
# 게임회사                                      1
# 스포츠구단                                     1
# 반도체                                       1
# 국내 대기업 it 계열과 해외기업(특히 자동차 관련)             1
# 바이오헬스 분야 기업                               1
# 공기업 전산직 통계직무                              1
# IT 기업과 제조업 분야 대기업의 IT계열 직무 둘다 궁금함         1
# 대학원 박사과정생 혹은 포닥                           1
# 생명정보 계열                                   1
# 국내외 빅테크 IT 계열                             1
# 데이터 센트릭 AI관련 계열                           1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 카테고리: 22개 (통합 대상)
# ============================================================
# 📌 [inflow_route]
#    - 총 카테고리 종류: 14개
# ------------------------------
# inflow_route
# 에브리타임                               759
# 인스타그램                               277
# 지인 추천                               155
# 기존 학회원 또는 운영진                       150
# 대외활동 사이트(링커리어, 캠퍼스픽, 캠퍼즈, 위비티 등)    117
# 기존 BDA 오픈채팅방                         89
# 직장인 커뮤니티(블라인드, 링크드인 등)                5
# 기타                                    2
# 인터넷 검색                                2
# B.D.A 행사 (잡페스티벌, WAVE)                2
# 교내 플랫폼 (에브리타임 X)                      1
# 기존 BDA 학회원                            1
# bda 9기활동                              1
# 네이버 블로그                               1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 카테고리: 8개 (통합 대상)
# ============================================================
# 📌 [incumbents_lecture_scale]
#    - 총 카테고리 종류: 10개
# ------------------------------
# incumbents_lecture_scale
# 3~50명 내외의 강의 리스너와 1명의 현직자                                     948
# 100명 이상의 리스너와 10명 이상의 현직자                                     408
# 10명 내외의 강의 리스너와 1명의 현직자                                       196
# 상관없음                                                            3
# 100명 이상의 리스너와 1-2명의 현직자                                         2
# 100명 이상의 리스너와 3명의 현직자                                           1
# ...                                                             1
# 100명 이상의 리스너와 3명 이상의 현직자                                        1
# 100명 이상의 강의리스너와 1명 현직자                                          1
# 온라인의 경우 3~50명 내외의 강의 리스너 / 오프라인의 경우 10명 내외의 강의 리스너를 희망합니다.      1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 카테고리: 7개 (통합 대상)
# ============================================================
# 📌 [whyBDA]
#    - 총 카테고리 종류: 10개
# ------------------------------
# whyBDA
# 혼자 공부하기 어려워서                                         648
# 큰 규모인 만큼, 커리큘럼이나 운영 등 관리가 잘 될것 같아서                   323
# BDA 학회원만의 혜택을 누리고 싶어서(현직자 강연, 잡 페스티벌, 기업연계 공모전 등)    146
# 이전 기수에 매우 만족해서                                       146
# 현직자의 강의를 듣고 싶어서                                      131
# 시간적으로 부담이 없어서                                         96
# 학회 가입 시 코딩 테스트, 면접 등을 보지 않아서                          69
# 현직자 강연 등 BDA 학회원의 혜택과 큰 규모인 만큼 관리가 잘 될 것 같다는 기대        1
# 강연, 기업연계 및 공모전 참여로 능력 향상                               1
# 학교에 빅데이터 학회가 없어서                                       1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 카테고리: 3개 (통합 대상)
# ============================================================

# %%
# ---------------------------------------------------------
# 설정
# ---------------------------------------------------------
MIN_FREQ = 5   # 5개 이하는 희소값으로 간주
RARE_LABEL = '희소' # 통합할 이름 (Others 대신 한글로 '희소')

# 대상 변수 6개
rare_targets = [
    'what_to_gain', 
    'incumbents_lecture', 
    'incumbents_company_level', 
    'inflow_route', 
    'incumbents_lecture_scale',
    'whyBDA'
]

print(f"🚀 희소값 통합 및 인코딩 시작 (기준: {MIN_FREQ}개 이하 -> '{RARE_LABEL}')")
print("=" * 60)

for col in rare_targets:
    if col not in df_all.columns:
        print(f"⚠️ {col} 없음 - 스킵")
        continue
    
    # 1. 빈도수 계산
    # (단일 선택이므로 그냥 value_counts 쓰면 됨)
    val_counts = df_all[col].value_counts()
    
    # 2. 희소값 식별 (5개 이하)
    rare_vals = val_counts[val_counts <= MIN_FREQ].index.tolist()
    
    # 3. 희소값 통합 적용
    if len(rare_vals) > 0:
        print(f"📌 [{col}]")
        print(f"   - 희소값 {len(rare_vals)}개 발견 -> '{RARE_LABEL}'로 통합")
        print(f"   - 목록: {rare_vals}")
        
        # replace로 한 번에 변경
        df_all[col] = df_all[col].replace(rare_vals, RARE_LABEL)
    else:
        print(f"📌 [{col}] - 희소값 없음")
        
    # 4. 인코딩 실행 (이제 안심하고 get_dummies)
    # (희소값들은 모두 '희소'라는 하나의 컬럼으로 모이게 됨)
    # (★ 수정: dtype=int)
    dummies = pd.get_dummies(df_all[col], prefix=col, dtype=int)
    
    # 5. 병합 및 원본 삭제
    df_all = pd.concat([df_all, dummies], axis=1)
    df_all.drop(columns=[col], inplace=True)
    
    # 결과 확인
    new_cols = dummies.columns.tolist()
    print(f"   -> {len(new_cols)}개 변수 생성: {new_cols}")
    print("-" * 60)

print(f"🎉 최종 컬럼 수: {df_all.shape[1]}")
# Out:
# 🚀 희소값 통합 및 인코딩 시작 (기준: 5개 이하 -> '희소')
# ============================================================
# 📌 [what_to_gain]
#    - 희소값 8개 발견 -> '희소'로 통합
#    - 목록: ['기초적인 python, sql 지식 숙지', '위 항목 전체', '공모전과 프로젝트', '사실 한가지를 고르기 어렵습니다..ㅠㅠ 학회를 통해 위의 4가지와 협업에 계신 전문가님들에게 유익한 정보를 얻고 소중한 경험을 하고 싶습니다.', '분석 역량, 공모전 경험, 인적 네트워크', '개인적으로는 데이터 분석 역량을 키우고, 인적 네트워크를 다져 프로젝트 등 경험과 실적을 쌓을 수 있는 힘을 기르고 또 그렇게 하기 위함 ', '취업팁', '위 모두 ..!']
#    -> 5개 변수 생성: ['what_to_gain_공모전 경험', 'what_to_gain_데이터 분석 역량', 'what_to_gain_인적 네트워크', 'what_to_gain_프로젝트 경험', 'what_to_gain_희소']
# ------------------------------------------------------------
# 📌 [incumbents_lecture]
#    - 희소값 8개 발견 -> '희소'로 통합
#    - 목록: ['커리어 패스 과정과 직무 강의 둘다 궁금합니다 ', '원동력', '위 항목 전부 다', '위에 3가지 모두 듣고 싶습니다', '위 3개 전부 다', '취업하기 위해 준비했던 각종 데이터 관련 경험들', '커리어패스, 산업 트렌드', '커리어 패스 과정과 직무 강의를 듣고 싶습니다']
#    -> 4개 변수 생성: ['incumbents_lecture_산업 트렌드 (예시: ChatGPT로 인한 직무 변화)', 'incumbents_lecture_직무 강의 (예시: 실무 진행 방식 및 직무 준비생을 위한 팁)', 'incumbents_lecture_커리어 패스 과정 (예시: 비전공자/전공자의 취업 준비 및 이직 과정)', 'incumbents_lecture_희소']
# ------------------------------------------------------------
# 📌 [incumbents_company_level]
#    - 희소값 22개 발견 -> '희소'로 통합
#    - 목록: ['국내와 해외 기업 현직자 모두에게 들었으면 좋겠다.', '배터리 관련 기업', '바이오인공지능 계열', '국내외 반도체 기업', '은행 및 보험 쪽 IT', '잘 모르겠음', '국내 대기업 IT 계열과 해외 기업 현직자에게 가장 듣고 싶습니다', '국내 빅테크 IT계열, 해외 기업 둘 다', '...', '공간정보 관련 직무 계열', '1순위: 국내 대기업 IT 계열. 2순위: 해외 기업(빅테크)', '게임회사', '스포츠구단', '반도체', '국내 대기업 it 계열과 해외기업(특히 자동차 관련)', '바이오헬스 분야 기업', '공기업 전산직 통계직무', 'IT 기업과 제조업 분야 대기업의 IT계열 직무 둘다 궁금함', '대학원 박사과정생 혹은 포닥', '생명정보 계열', '국내외 빅테크 IT 계열', '데이터 센트릭 AI관련 계열']
#    -> 5개 변수 생성: ['incumbents_company_level_국내 대기업 IT 계열 (금융, 제조 ...)', 'incumbents_company_level_국내 빅테크 IT 계열 (네카라쿠배당토)', 'incumbents_company_level_스타트업 C-level', 'incumbents_company_level_해외 기업 (빅테크)', 'incumbents_company_level_희소']
# ------------------------------------------------------------
# 📌 [inflow_route]
#    - 희소값 8개 발견 -> '희소'로 통합
#    - 목록: ['직장인 커뮤니티(블라인드, 링크드인 등)', '기타', '인터넷 검색', 'B.D.A 행사 (잡페스티벌, WAVE)', '교내 플랫폼 (에브리타임 X)', '기존 BDA 학회원', 'bda 9기활동', '네이버 블로그']
#    -> 7개 변수 생성: ['inflow_route_기존 BDA 오픈채팅방', 'inflow_route_기존 학회원 또는 운영진', 'inflow_route_대외활동 사이트(링커리어, 캠퍼스픽, 캠퍼즈, 위비티 등)', 'inflow_route_에브리타임', 'inflow_route_인스타그램', 'inflow_route_지인 추천', 'inflow_route_희소']
# ------------------------------------------------------------
# 📌 [incumbents_lecture_scale]
#    - 희소값 7개 발견 -> '희소'로 통합
#    - 목록: ['상관없음', '100명 이상의 리스너와 1-2명의 현직자', '100명 이상의 리스너와 3명의 현직자', '...', '100명 이상의 리스너와 3명 이상의 현직자', '100명 이상의 강의리스너와 1명 현직자 ', '온라인의 경우 3~50명 내외의 강의 리스너 / 오프라인의 경우 10명 내외의 강의 리스너를 희망합니다.']
#    -> 4개 변수 생성: ['incumbents_lecture_scale_100명 이상의 리스너와 10명 이상의 현직자', 'incumbents_lecture_scale_10명 내외의 강의 리스너와 1명의 현직자', 'incumbents_lecture_scale_3~50명 내외의 강의 리스너와 1명의 현직자', 'incumbents_lecture_scale_희소']
# ------------------------------------------------------------
# 📌 [whyBDA]
#    - 희소값 3개 발견 -> '희소'로 통합
#    - 목록: ['현직자 강연 등 BDA 학회원의 혜택과 큰 규모인 만큼 관리가 잘 될 것 같다는 기대', '강연, 기업연계 및 공모전 참여로 능력 향상', '학교에 빅데이터 학회가 없어서 ']
#    -> 8개 변수 생성: ['whyBDA_BDA 학회원만의 혜택을 누리고 싶어서(현직자 강연, 잡 페스티벌, 기업연계 공모전 등)', 'whyBDA_시간적으로 부담이 없어서', 'whyBDA_이전 기수에 매우 만족해서', 'whyBDA_큰 규모인 만큼, 커리큘럼이나 운영 등 관리가 잘 될것 같아서', 'whyBDA_학회 가입 시 코딩 테스트, 면접 등을 보지 않아서', 'whyBDA_현직자의 강의를 듣고 싶어서', 'whyBDA_혼자 공부하기 어려워서', 'whyBDA_희소']
# ------------------------------------------------------------
# 🎉 최종 컬럼 수: 110

# %% [markdown]
# 2. 다중 선택 가능 변수
#
# [desired_certificate], [desired_job]: 데이터 수가 13 이하인 카테고리를 모두 ‘희소’로 통합
#
# [certificate_acquisition]: 데이터 수가 6 이하인 카테고리를 모두 ‘희소’로 통합
#
# [onedayclass_topic]: 데이터 수가 3 이하인 카테고리를 모두 ‘희소’로 통합
#
# [major_field]:  'IT (컴퓨터 공학 포함)', '공학 (컴퓨터 공학 제외)', '자연과학', '자연고학' 를 '이공계'로, '경영학', '사회과학', '인문학', '경제통상학', '교육학', '법학' 를 '인문계'로 통합, 나머지 기존 '예체능', '의약학', 'Unknown'은 그대로 유지.

# %%
# 점검 대상
multi_targets = [
    'certificate_acquisition', 
    'desired_certificate', 
    'onedayclass_topic', 
    'desired_job', 
    'major_field'
]

# 괄호 안 콤마 보호 함수 (재사용)
def protect_comma(text):
    if pd.isna(text): return text
    text = str(text)
    return re.sub(r'\([^)]*\)', lambda m: m.group(0).replace(',', '&'), text)

print("🔍 [사전 점검] 다중 선택 변수 알맹이 현황 (콤마 보호 적용)")
print("=" * 60)
pd.set_option('display.max_rows', None)

for col in multi_targets:
    if col in df_all.columns:
        print(f"📌 [{col}]")
        
        # 1. 보호 -> 쪼개기 -> 복원 (안전 분리)
        temp_series = df_all[col].apply(protect_comma).astype(str)
        tokens = temp_series.str.split(',').explode().str.strip()
        tokens = tokens.str.replace('&', ',') # 다시 콤마로 복원해서 확인
        
        # 2. 빈도수 확인
        token_counts = tokens.value_counts()
        
        print(f"   - 총 알맹이 종류: {len(token_counts)}개")
        print("-" * 30)
        print(token_counts)
        
        # 5개 이하인 것들 카운트
        rare_cnt = (token_counts <= 5).sum()
        print("-" * 30)
        print(f"⚠️ [알림] 5개 이하 희소 알맹이: {rare_cnt}개 (통합 대상)")
        print("=" * 60)
        
    else:
        print(f"⚠️ {col} 컬럼이 존재하지 않습니다.")

pd.reset_option('display.max_rows')
# Out:
# 🔍 [사전 점검] 다중 선택 변수 알맹이 현황 (콤마 보호 적용)
# ============================================================
# 📌 [certificate_acquisition]
#    - 총 알맹이 종류: 33개
# ------------------------------
# certificate_acquisition
# 없음                                  931
# ADsP                                421
# SQLD                                301
# 컴퓨터 활용능력(1,2급)                       99
# 구글 애널리스트                             51
# 빅데이터 분석 기사                           38
# 정보처리기사                               36
# 사회조사분석사 2급                            5
# 기타                                    4
# 컴퓨터활용능력                               3
# 준비중: ADsP                             2
# 준비중                                   2
# 준비중: SQLD                             2
# 사회조사분석사2급                             2
# 정보처리기능사                               2
# DAsP                                  2
# 태블로                                   2
# OA 자격증                                1
# 정보처리산업기사                              1
# AWS                                   1
# MOS EXCEL EXPERT                      1
# 사조사 2급                                1
# SAS Adanced                           1
# SAS Base                              1
# AWS Certified Cloud Practitioner      1
# Aws AI                                1
# 사회조사분석가 2급                            1
# 네트워크관리사 2급                            1
# pc정비사 2급                              1
# Dasp                                  1
# 태블로 관련 자격증                            1
# MOS Master                            1
# 사조사2급                                 1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 알맹이: 26개 (통합 대상)
# ============================================================
# 📌 [desired_certificate]
#    - 총 알맹이 종류: 56개
# ------------------------------
# desired_certificate
# 빅데이터 분석 기사                             936
# SQLD                                   884
# ADsP                                   711
# 정보처리기사                                 601
# 컴퓨터 활용능력(1,2급)                         303
# 구글 애널리스트                               300
# 태블로 관련 자격증                             278
# 없음                                      12
# ADP                                      6
# 사회조사분석사                                  4
# SQLP                                     3
# .                                        3
# 품질경영기사                                   3
# Adp                                      2
# 사회조사분석사2급                                1
# 클라우드 관련 자격증                              1
# SQLD는 합격여부를 기다리는중                        1
# ADsP는 8/30 발표 기다리는중(시험 응시)               1
# ADO                                      1
# sqld 시험 응시는 완료. 발표아직안남                   1
# 자격증에는 크게 관심 없습니다                         1
# 사회조사분석사 2급                               1
# 딱히 없음                                    1
# sqlp 등                                   1
# 6sigma                                   1
# x                                        1
# AWS CLF                                  1
# AICE                                     1
# 오픽                                       1
# 아직은 없음                                   1
# 자격증은 아직 잘 모르겠음                           1
# 아직 다 뭔지 잘 몰라서...                         1
# 자격증은 취득 예정 없음                            1
# AI 자격증(AICE)                             1
# 아직 계획없습니다.                               1
# 경영정보시각화능                                 1
# Pccp                                     1
# 한능검                                      1
# 네트워크관리사2급                                1
# 품질경영                                     1
# 리눅스마스터                                   1
# SQL 개발자                                  1
# 리눅스 마스터 2급                               1
# 아직 없음                                    1
# AWS                                      1
# 사조사 2급 실기                                1
# Aice                                     1
# AFPK                                     1
# 아직 생각없음                                  1
# AICE Associate                           1
# 사조사                                      1
# 빅데이터 분석 기사 따면 좋을 것 같지만 아직 예정은 없습니다.      1
# 투자자산운용사                                  1
# 자격증을 따고싶은 건 없음                           1
# JLPT                                     1
# TOEFL                                    1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 알맹이: 47개 (통합 대상)
# ============================================================
# 📌 [onedayclass_topic]
#    - 총 알맹이 종류: 34개
# ------------------------------
# onedayclass_topic
# SQL 응용                                           618
# Python 응용 (ex- 머신러닝을 이용한 추천시스템 구축)               508
# 데이터 시각화 (Matplotlib, Seaborn 등)                  427
# 머신러닝 / 딥러닝 응용                                    394
# Python 응용                                        333
# Tableau를 이용한 데이터 시각화                             317
# AI모델 구축                                          315
# 데이터 엔지니어를 위한 Hadoop 맛보기                          200
# 웹 크롤링                                            181
# 태블로                                                2
# RNN과 같이 심화된 내용으로 시야를  넓히고 싶습니다. 또는 chatgpt 활용      1
# powebi 같은 학교 수업에서 듣지 못하는 수업을 듣고 싶습니다               1
# 태블로 학습                                             1
# 구글 애널리틱스                                           1
#                                                    1
# 금융공학                                               1
# CNN                                                1
# 금융데이터                                              1
# 포트폴리오 A to Z                                       1
# 데이터 엔지니어링(파이프라인설계)                                 1
# 테블로                                                1
# Power Bi 강연                                        1
# 공모전 수상 tip                                         1
# 파워비아이                                              1
# airflow강의                                          1
# aws로 시각화 자동배포                                      1
# Airflow                                            1
# Cloud (AWS, GCP, Azure) 사용법 안내                     1
# 잘모름                                                1
# 엑셀                                                 1
# 비즈니스 데이터 분석 사례                                     1
# 포트폴리오 작성 요령 등                                      1
# ai기반 서비스 기획                                        1
# 현업에서 사용하는 SQLD                                     1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 알맹이: 25개 (통합 대상)
# ============================================================
# 📌 [desired_job]
#    - 총 알맹이 종류: 126개
# ------------------------------
# desired_job
# B. 데이터 분석가                                      858
# C. 데이터 사이언티스트                                   430
# A. 데이터 엔지니어                                     239
# D. 인공지능 전문가                                     178
# I. 마케터                                          153
# G. PM/서비스 기획자                                   145
# E. 소프트웨어 개발자                                     97
# H. 자연과학계열 연구자                                    53
# J. MD                                            33
# F. UI/UX 디자이너                                    29
# 반도체 엔지니어                                         12
#                                                   6
# 미정                                                4
# 컨설턴트                                              2
# 영업                                                2
# 품질                                                2
# 품질관리                                              2
# 반도체                                               2
# 보험계리사                                             2
# 계리사                                               2
# 품질관리직                                             2
# 금융공기업                                             1
# 인사팀                                               1
# 채용 데이터 분석 및 HR 전문가                                1
# 정보보안                                              1
# 아직 뚜렷한 희망 직무를 정하지 못했습니다                           1
# 도시계획                                              1
# 생산/공정기술                                           1
# ESG 경영/공시 직무                                      1
# RA                                                1
# DX(디지털 트랜스포메이션)직무 희망                              1
# 국제회의기획자                                           1
# 생체?세포계열 연구자                                       1
# 의공기사                                              1
# 반도체 공정설계                                          1
# 로봇설계                                              1
# 클라우드                                              1
# 없음                                                1
# 반도체 품질 관리                                         1
# 외교관                                               1
# SCM                                               1
# 화학공장 생산관리 엔지니어                                    1
# SCM관련 직무                                          1
# 아직 제대로 알지 못해 학회 활동을 통해 진로 직업에 자세히 대해 배우고 싶다.      1
# 생산 / 품질 엔지니어                                      1
# 금융관리                                              1
# 생산관리/생산기술                                         1
# 반도체 공정                                            1
# 경영컨설턴트                                            1
# 경영직무                                              1
# HRM HRD                                           1
# HR 매니저                                            1
# 아직 모르겠음                                           1
# 생산관리                                              1
# 물류/SCM                                            1
# 산림빅데이터 전문가                                        1
# 연구원/보안분야연구원                                       1
# 회계 직무                                             1
# 글로벌 전략                                            1
# 전력 분석관                                            1
# 아직 없습니다..                                         1
# PO                                                1
# 아직 결정하지 못함                                        1
# 생산                                                1
# 상품개발/계리                                           1
# UX 리서처                                            1
# 금융                                                1
# 반도체(평가 및 분석, 수율향상, 소자개발 및 불량분석 등)                 1
# Hr                                                1
# 이차전지 엔지니어                                         1
# 반도체 공정기술 엔지니어                                     1
# 공간정보 관련 직무                                        1
# 소재 엔지니어                                           1
# 스마트로지스틱                                           1
# 전략기획                                              1
# 픔질관리                                              1
# 토목                                                1
# 생산기술 엔지니어 /공정 기술엔지니어                              1
# HR 애널리틱스                                          1
# 로보틱스 연구원                                          1
# 반도체 공정기술 연구원                                      1
# 반도체 공정기술                                          1
# 생산관리자                                             1
# 평가및분석                                             1
# 배터리 소재 엔지니어                                       1
# 직장인이 아님                                           1
# 공기업                                               1
# 금융종사자                                             1
# 생산관리 / 품질관리 엔지니어                                  1
# 데이터사이언티스트/피엠/퍼포먼스마케팅                              1
# 헤드헌터                                              1
# HR전문가                                             1
# 핀테크 기업                                            1
# 데이터 처리 관련 직종                                      1
# 마케터                                               1
# 금융 등 다양한 분야에 관심을 두고 있습니다.                         1
# 반도체 연구원                                           1
# 사회과학계열 연구자                                        1
# 데이터 저널리스트                                         1
# 공정 엔지니어                                           1
# 웹개발자 외 it 직종                                      1
# 스포츠 전력 분석가                                        1
# 데이터 컨설턴트                                          1
# 데이터 직무는 아님                                        1
# 계획없음                                              1
# 자산운용사                                             1
# HR 전문가                                            1
# 생산/품질관리                                           1
# 퍼포먼스 마케터                                          1
# 금공                                                1
# 아직 잘 모르겠습니다                                       1
# 재무 기획                                             1
# 정보보안 전문가                                          1
# 데이터 사이언스                                          1
# AI                                                1
# 소프트웨어 개발자 내 진로 고민중                                1
# 은행원                                               1
# 공인회계사                                             1
# 아직 미정                                             1
# 경영 컨설턴트                                           1
# 출판기획                                              1
# PD                                                1
# 품질관리 직무                                           1
# 보안관련직무                                            1
# 인문과학계열 연구자                                        1
# 교사                                                1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 알맹이: 114개 (통합 대상)
# ============================================================
# 📌 [major_field]
#    - 총 알맹이 종류: 13개
# ------------------------------
# major_field
# IT (컴퓨터 공학 포함)    467
# 공학 (컴퓨터 공학 제외)    319
# 경영학               293
# 자연과학              225
# 사회과학              217
# 인문학               129
# Unknown            97
# 경제통상학              86
# 예체능                30
# 교육학                21
# 의약학                16
# 법학                  9
# 자연고학                1
# Name: count, dtype: int64
# ------------------------------
# ⚠️ [알림] 5개 이하 희소 알맹이: 1개 (통합 대상)
# ============================================================

# %%
# 공통 함수
def protect_comma(text):
    if pd.isna(text): return text
    text = str(text)
    return re.sub(r'\([^)]*\)', lambda m: m.group(0).replace(',', '&'), text)

# 설정
rare_rules = [
    (['desired_certificate', 'desired_job'], 13), 
    (['certificate_acquisition'], 6),             
    (['onedayclass_topic'], 3)                    
]

print("🚀 [최종 수정] 다중 선택 변수 희소값 통합 (콤마 보호 유지)")
print("=" * 60)

for cols, threshold in rare_rules:
    for col in cols:
        if col not in df_all.columns: continue
        
        # 1. 기준 파악용 (일단 쪼개서 빈도수 계산)
        temp_series = df_all[col].apply(protect_comma).astype(str)
        tokens = temp_series.str.split(',').explode().str.strip()
        # 기준 잡을 때는 &를 ,로 복원해서 확인 (그래야 정확한 이름으로 매칭)
        tokens_restored = tokens.str.replace('&', ',') 
        
        token_counts = tokens_restored.value_counts()
        rare_vals = token_counts[token_counts <= threshold].index.tolist()
        rare_set = set(rare_vals)
        
        print(f"📌 [{col}] 기준: {threshold}개 이하 ({len(rare_vals)}개 통합)")
        
        # 2. 치환 및 보호 상태 유지 (핵심!)
        def replace_rare_and_keep_protected(text):
            if pd.isna(text): return text
            # 들어올 때는 이미 보호된 상태 (예: "컴활(1& 2급), SQLD")
            parts = [t.strip() for t in text.split(',')]
            new_parts = []
            
            for p in parts:
                # 희소값인지 확인할 때는 ,로 복원해서 비교
                original_name = p.replace('&', ',')
                
                if original_name in rare_set:
                    new_parts.append('희소')
                else:
                    # ★ 희소가 아니면, 원래의 보호된 상태(p)를 그대로 쓴다! ★
                    # (즉, &가 들어있는 상태로 유지)
                    new_parts.append(p)
            
            # 다시 콤마로 연결
            return ','.join(sorted(list(set(new_parts))))

        # 3. 적용 (보호된 문자열 반환)
        cleaned_series = temp_series.apply(replace_rare_and_keep_protected)
        
        # 4. 인코딩 (이제 &가 있으니 안 찢어짐!)
        # (★ 수정: dtype=int)
        dummies = cleaned_series.str.get_dummies(sep=',').astype(int)
        dummies = dummies.add_prefix(f"{col}_")
        
        # 5. 컬럼명 복원 (& -> ,)
        # 이제서야 비로소 컬럼명에 있는 &를 콤마로 바꿔줌
        new_cols = [c.replace('&', ',') for c in dummies.columns]
        dummies.columns = new_cols
        
        # 6. 병합
        df_all = pd.concat([df_all, dummies], axis=1)
        df_all.drop(columns=[col], inplace=True)
        
        print(f"   -> {len(new_cols)}개 생성: {new_cols}")
        print("-" * 30)


# ---------------------------------------------------------
# 2. major_field (여긴 괄호 콤마 문제가 없어서 그대로 둠)
# ---------------------------------------------------------
mapping_rule = {
    'IT (컴퓨터 공학 포함)': '이공계',
    '공학 (컴퓨터 공학 제외)': '이공계',
    '자연과학': '이공계',
    '자연고학': '이공계',
    '경영학': '인문계',
    '사회과학': '인문계',
    '인문학': '인문계',
    '경제통상학': '인문계',
    '교육학': '인문계',
    '법학': '인문계'
}

col = 'major_field'
if col in df_all.columns:
    print(f"📌 [{col}] 계열 통합")
    def apply_mapping(text):
        if pd.isna(text): return text
        parts = [t.strip() for t in text.split(',')]
        new_parts = []
        for p in parts:
            if p in mapping_rule:
                new_parts.append(mapping_rule[p])
            else:
                new_parts.append(p)
        return ','.join(sorted(list(set(new_parts))))

    cleaned_series = df_all[col].astype(str).apply(apply_mapping)
    # (★ 수정: dtype=int)
    dummies = cleaned_series.str.get_dummies(sep=',').astype(int)
    dummies = dummies.add_prefix(f"{col}_")
    new_cols = dummies.columns.tolist()
    
    df_all = pd.concat([df_all, dummies], axis=1)
    df_all.drop(columns=[col], inplace=True)
    print(f"   -> {len(new_cols)}개 생성: {new_cols}")

print("=" * 60)
print(f"🎉 처리 완료! 최종 컬럼 수: {df_all.shape[1]}")
# Out:
# 🚀 [최종 수정] 다중 선택 변수 희소값 통합 (콤마 보호 유지)
# ============================================================
# 📌 [desired_certificate] 기준: 13개 이하 (49개 통합)
#    -> 8개 생성: ['desired_certificate_ADsP', 'desired_certificate_SQLD', 'desired_certificate_구글 애널리스트', 'desired_certificate_빅데이터 분석 기사', 'desired_certificate_정보처리기사', 'desired_certificate_컴퓨터 활용능력(1,2급)', 'desired_certificate_태블로 관련 자격증', 'desired_certificate_희소']
# ------------------------------
# 📌 [desired_job] 기준: 13개 이하 (116개 통합)
#    -> 11개 생성: ['desired_job_A. 데이터 엔지니어', 'desired_job_B. 데이터 분석가', 'desired_job_C. 데이터 사이언티스트', 'desired_job_D. 인공지능 전문가', 'desired_job_E. 소프트웨어 개발자', 'desired_job_F. UI/UX 디자이너', 'desired_job_G. PM/서비스 기획자', 'desired_job_H. 자연과학계열 연구자', 'desired_job_I. 마케터', 'desired_job_J. MD', 'desired_job_희소']
# ------------------------------
# 📌 [certificate_acquisition] 기준: 6개 이하 (26개 통합)
#    -> 8개 생성: ['certificate_acquisition_ADsP', 'certificate_acquisition_SQLD', 'certificate_acquisition_구글 애널리스트', 'certificate_acquisition_빅데이터 분석 기사', 'certificate_acquisition_없음', 'certificate_acquisition_정보처리기사', 'certificate_acquisition_컴퓨터 활용능력(1,2급)', 'certificate_acquisition_희소']
# ------------------------------
# 📌 [onedayclass_topic] 기준: 3개 이하 (25개 통합)
#    -> 10개 생성: ['onedayclass_topic_AI모델 구축', 'onedayclass_topic_Python 응용', 'onedayclass_topic_Python 응용 (ex- 머신러닝을 이용한 추천시스템 구축)', 'onedayclass_topic_SQL 응용', 'onedayclass_topic_Tableau를 이용한 데이터 시각화', 'onedayclass_topic_데이터 시각화 (Matplotlib, Seaborn 등)', 'onedayclass_topic_데이터 엔지니어를 위한 Hadoop 맛보기', 'onedayclass_topic_머신러닝 / 딥러닝 응용', 'onedayclass_topic_웹 크롤링', 'onedayclass_topic_희소']
# ------------------------------
# 📌 [major_field] 계열 통합
#    -> 5개 생성: ['major_field_Unknown', 'major_field_예체능', 'major_field_의약학', 'major_field_이공계', 'major_field_인문계']
# ============================================================
# 🎉 처리 완료! 최종 컬럼 수: 147

# %% [markdown]
# [major1_1], [major1_2]
#
# -> 학습 세트만 봤을 때는 카테고리가 둘 다 10개 남짓이었지만 테스트 세트와 합쳐서 보니 300개, 163개로 종류 대폭 증가.
#
# 따라서 '이공계', '상경계', '자연_의약계', '인문_사회계', '예체능계'로 묶고, 이외의 값은 '희소'로 통합.
#
# 이전에 결측치 처리했던 'Unknown'과 '없음'은 그대로 유지.

# %%
# 전공 변수 확인
major_cols = ['major1_1', 'major1_2']

print("🔍 [정밀 점검] 전공 변수 카테고리 분포 확인")
print("=" * 60)
# 카테고리가 많으므로 전체 출력 제한 해제
pd.set_option('display.max_rows', None)

for col in major_cols:
    if col in df_all.columns:
        val_counts = df_all[col].value_counts(dropna=False)
        print(f"📌 [{col}] - 총 종류: {len(val_counts)}개")
        print("-" * 30)
        # 너무 많으면 상위 50개랑 하위 20개만 보는 게 나을 수도 있지만, 일단 요청대로
        print(val_counts) 
        print("=" * 60)
    else:
        print(f"⚠️ {col} 없음")

pd.reset_option('display.max_rows')
# Out:
# 🔍 [정밀 점검] 전공 변수 카테고리 분포 확인
# ============================================================
# 📌 [major1_1] - 총 종류: 300개
# ------------------------------
# major1_1
# IT(컴퓨터 공학 포함)                                                                              253
# 경영학                                                                                        178
# 자연과학                                                                                        97
# Unknown                                                                                     93
# 사회과학                                                                                        57
# 인문학                                                                                         48
# 경영학과                                                                                        47
# 통계학과                                                                                        46
# 경제통상학                                                                                       36
# 응용통계학과                                                                                      30
# 의약학                                                                                         29
# 경영학부                                                                                        26
# 컴퓨터공학과                                                                                      23
# 정보통계학과                                                                                      19
# 수학과                                                                                         18
# 산업공학과                                                                                       15
# 예체능                                                                                         15
# 데이터사이언스학과                                                                                   14
# 소프트웨어학과                                                                                     13
# 산업경영공학과                                                                                     12
# 인공지능학과                                                                                      11
# 정보통신공학과                                                                                     11
# 교육학                                                                                         10
# 경제학과                                                                                        10
# 컴퓨터공학부                                                                                      10
# 심리학과                                                                                         8
# 컴퓨터학부                                                                                        8
# 문헌정보학과                                                                                       8
# 사회학과                                                                                         7
# 산업시스템공학과                                                                                     7
# 국제학부                                                                                         7
# AI빅데이터융합경영학과                                                                                 6
# AI융합학부                                                                                       6
# 산업정보시스템공학과                                                                                   6
# 영어영문학과                                                                                       5
# 경영공학과                                                                                        5
# 정치외교학과                                                                                       5
# 경영정보학과                                                                                       5
# 국제통상학과                                                                                       4
# 신소재공학부                                                                                       4
# 소프트웨어학부                                                                                      4
# 시스템경영공학과                                                                                     4
# 경제학부                                                                                         4
# 행정학과                                                                                         4
# 정보시스템학과                                                                                      4
# 소프트웨어융합학과                                                                                    4
# 컴퓨터과학과                                                                                       4
# 소프트웨어공학과                                                                                     3
# 교육학과                                                                                         3
# 중어중문학과                                                                                       3
# 법학                                                                                           3
# 화학과                                                                                          3
# 데이터과학부                                                                                       3
# 전자전기공학부                                                                                      3
# 심리학부                                                                                         3
# 화학공학과                                                                                        3
# 국어국문학과                                                                                       3
# 신소재공학과                                                                                       3
# 산업데이터공학과                                                                                     3
# 의공학과                                                                                         3
# 물리학과                                                                                         3
# 영어교육학과                                                                                       2
# 생명정보융합학과                                                                                     2
# 미디어커뮤니케이션학과                                                                                  2
# Ai빅데이터융합경영학과                                                                                 2
# 관광경영학과                                                                                       2
# 스칸디나비아어학과                                                                                    2
# 데이터사이언스경영학과                                                                                  2
# 작곡학과                                                                                         2
# 디지털소프트웨어공학부                                                                                  2
# 교육공학과                                                                                        2
# 미디어커뮤니케이션학부                                                                                  2
# 노어학과                                                                                         2
# 아동심리학과                                                                                       2
# 데이터사이언스학부                                                                                    2
# 도시공학과                                                                                        2
# 정보사회학과                                                                                       2
# 언어학과                                                                                         2
# 국제물류학과                                                                                       2
# 의공학부                                                                                         2
# 도시사회학과                                                                                       2
# 전자공학과                                                                                        2
# 광고홍보학과                                                                                       2
# 빅데이터융합학과                                                                                     2
# 사학과                                                                                          2
# 인공지능공학과                                                                                      2
# 컴퓨터융합학부                                                                                      2
# 소비자경제학과                                                                                      2
# 스페인중남미학과                                                                                     2
# 컴퓨터학과                                                                                        2
# 약학과                                                                                          2
# 정보통계보험수리학과                                                                                   2
# 산업경영공학부                                                                                      2
# 빅데이터학과                                                                                       2
# 식품영양학과                                                                                       2
# 글로벌커뮤니케이션학부                                                                                  2
# 영어영문학부                                                                                       2
# 무역학과                                                                                         2
# 태국학과                                                                                         2
# 스포츠산업레저학과                                                                                    2
# 수리빅데이터학과                                                                                     2
# 기타                                                                                           2
# 빅데이터의료융합학과                                                                                   1
# ELLT학과                                                                                       1
# 금융학부                                                                                         1
# 사회체육학과                                                                                       1
# 미디어학과                                                                                        1
# 정보통계학부                                                                                       1
# 경영인텔리전스학과                                                                                    1
# 시스템생명공학과                                                                                     1
# 에너지시스템공학부                                                                                    1
# ICT융합학부                                                                                      1
# 영어학과                                                                                         1
# 한국사학과                                                                                        1
# 융합기계공학과                                                                                      1
# 창의기술경영학과                                                                                     1
# IT학부                                                                                         1
# 컴퓨터/AI학부                                                                                     1
# IT 융합학부                                                                                      1
# 컴퓨터소프트웨어학부                                                                                   1
# 인공지능공학부                                                                                      1
# 디지털소프트웨어공학과                                                                                  1
# 데이터사이언스융합학과                                                                                  1
# 루마니아학과                                                                                       1
# 수학교육학과                                                                                       1
# 융합인재학과                                                                                       1
# 건축공학과                                                                                        1
# 수리통계데이터사이언스학부 수학과                                                                            1
# 전기전자공학부                                                                                      1
# 수학통계학부 수학과                                                                                   1
# 산업경영학과                                                                                       1
# 항공기시스템공학과                                                                                    1
# AI&SW학부                                                                                      1
# 정경대학 통계학과                                                                                    1
# 컴퓨터과학부                                                                                       1
# it학부 컴퓨터정보공학과                                                                                1
# 융합반도체공학과                                                                                     1
# 의류학과                                                                                         1
# 바이오공학과                                                                                       1
# 공간디자인소비자학과                                                                                   1
# 전기생체공학부 생체공학과                                                                                1
# 무역학부                                                                                         1
# 기계항공공학부                                                                                      1
# 미디어학부                                                                                        1
# 빅데이터응옹통계학과                                                                                   1
# 동물생명공학과                                                                                      1
# AI빅데이터학과                                                                                     1
# Faculty of Resources Science and Technology 학과 Plant Resource Science and Management 학부      1
# 관광개발학과                                                                                       1
# 보건행정학과                                                                                       1
# 환경학과                                                                                         1
# 인문학부                                                                                         1
# 화공신소재공학부                                                                                     1
# 정보통신학부                                                                                       1
# 글로벌융합학부 데이터사이언스융합학과                                                                          1
# 빅데이터응용통계학과                                                                                   1
# 기계스마트산업공학부 스마트팩토리학과                                                                          1
# 지적학과                                                                                         1
# 휴먼기계바이오공학과                                                                                   1
# 글로벌미디어학부                                                                                     1
# 사회환경공학부                                                                                      1
# 소프트웨어융합대학 컴퓨터공학과                                                                             1
# 컴퓨터인공지능공학부                                                                                   1
# 바이오메디컬공학부                                                                                    1
# (졸업)언어정보학과/(재학)컴퓨터과학과                                                                        1
# 데이터과학과                                                                                       1
# 조경학과                                                                                         1
# 빅데이터응용학과                                                                                     1
# 바이오메디컬공학과                                                                                    1
# 국제관계학과                                                                                       1
# AI융합학부 AI학과                                                                                  1
# 경영정보학부                                                                                       1
# 수학통계학부                                                                                       1
# 생활과학대학 통합디자인학과                                                                               1
# 상경학부 글로벌경영학과                                                                                 1
# 전자통신공학과                                                                                      1
# 스페인어학과                                                                                       1
# 인공지능학부 인공지능                                                                                  1
# 아랍어학과                                                                                        1
# 실내건축학과                                                                                       1
# 소프트웨어학부 컴퓨터과학과                                                                               1
# 동양사학과                                                                                        1
# 글로벌문화학부                                                                                      1
# 나노과학공학과                                                                                      1
# 아시아문화학부 일본어문학과                                                                               1
# 의상학과                                                                                         1
# 데이터사이언스와 인공지능 학부                                                                             1
# 에너지화학공학과                                                                                     1
# 화공생명공학과                                                                                      1
# 중국어중국학과                                                                                      1
# 식품공학과                                                                                        1
# 일어일문학과                                                                                       1
# 국제금융학과                                                                                       1
# 정책학과                                                                                         1
# 농업경제학과                                                                                       1
# 첨단융합학부                                                                                       1
# 자유전공학부                                                                                       1
# 생명환경공학과                                                                                      1
# 유기재료공학과                                                                                      1
# 독어독문학과                                                                                       1
# 정보보안암호수학과                                                                                    1
# 환경생태공학부                                                                                      1
# 바이오시스템의과학부                                                                                   1
# 스포츠청소년지도학과                                                                                   1
# 터키•아제르바이잔어학과                                                                                 1
# 디지털미디어학과                                                                                     1
# 계량위험관리학과                                                                                     1
# 보건환경융합과학부                                                                                    1
# 수리데이터사이언스학과                                                                                  1
# 체코슬로바키아어학과                                                                                   1
# 글로벌금융경영학부                                                                                    1
# 국제사무학과                                                                                       1
# 응용수학과                                                                                        1
# Ai융합학부                                                                                       1
# 기계시스템디자인공학과                                                                                  1
# AI 자율주행시스템공학과                                                                                1
# 부동산학과                                                                                        1
# 산업보안학과                                                                                       1
# 정보융합학부                                                                                       1
# 정보통계학전공                                                                                      1
# 바이오발효융합학과                                                                                    1
# 융합전자공학부                                                                                      1
# 캄퓨터공학부 소프트웨어공학과                                                                              1
# 국제법무학과                                                                                       1
# 정보통신공학부                                                                                      1
# 금융수학과                                                                                        1
# AI학과                                                                                         1
# 몽골어학과                                                                                        1
# 방송디지털미디어학과                                                                                   1
# 러시아유라시아학과                                                                                    1
# 소프트웨어학부 컴퓨터과학전공학과                                                                            1
# 바이오메디컬화학공학과                                                                                  1
# 토목건축공학과                                                                                      1
# 미디어소프트웨어학과                                                                                   1
# 의예과/의학과                                                                                      1
# 데이터 사이언스 학과                                                                                  1
# 융합생명공학과                                                                                      1
# 전자전기공학과                                                                                      1
# 스마트시티학과                                                                                      1
# 소프트웨어융합공학과                                                                                   1
# 데이터정보학과                                                                                      1
# 걍영학부                                                                                         1
# 디지털경영학부                                                                                      1
# 전기공학과                                                                                        1
# 화공신소재공학과                                                                                     1
# 포르투갈어학과                                                                                      1
# 융합보안학과                                                                                       1
# 공간정보공학과                                                                                      1
# 데이터경영학과                                                                                      1
# 전자물리학과                                                                                       1
# 중국어통번역학과                                                                                     1
# 반도체전자공학부                                                                                     1
# 산업시스템학과                                                                                      1
# 경영학부 경영학과                                                                                    1
# 아시아문화학부                                                                                      1
# 사회과학대학 경제학과                                                                                  1
# AI소프트웨어융합학부 컴퓨터공학과                                                                           1
# 산업경영정보공학과                                                                                    1
# 경제금융학부                                                                                       1
# 스포츠건강재황학과                                                                                    1
# 호텔관광경영학과                                                                                     1
# 통계데이터과학과                                                                                     1
# 휴먼기계바이오공학부                                                                                   1
# 통계 데이터과학과                                                                                    1
# 바이오화학공학과                                                                                     1
# IT경영학과                                                                                       1
# 기계공학부                                                                                        1
# 영어통번역(EICC)학과                                                                                1
# 한문학과                                                                                         1
# 금융빅데이터학부                                                                                     1
# 스포츠과학과                                                                                       1
# 화공생명공학부                                                                                      1
# 신소재공학부 정보소재공학과                                                                               1
# 외식경영학과                                                                                       1
# 스마트유통물류학과                                                                                    1
# 산업융합학부                                                                                       1
# 글로벌스포츠산업학부                                                                                   1
# 베트남어학과                                                                                       1
# 글로벌통상학과                                                                                      1
# 건설환경공학부                                                                                      1
# 한국어문학부                                                                                       1
# Sw융합학부 sw융합경제경영학과                                                                            1
# 금융정보공학과                                                                                      1
# 의료공학과                                                                                        1
# 컴퓨터소프트웨어공학과                                                                                  1
# 경영학부 글로벌금융학과                                                                                 1
# 법학부                                                                                          1
# 도시교통공학과                                                                                      1
# 기계자동차공학과                                                                                     1
# 중국학과                                                                                         1
# 광고홍보학부                                                                                       1
# 지리교육학과                                                                                       1
# 컴퓨터교육학과                                                                                      1
# 수의학과                                                                                         1
# AI융합학부 지능형 IoT학과                                                                             1
# 스마트모빌리티학과                                                                                    1
# 바둑학과                                                                                         1
# 생명공학부                                                                                        1
# 의생명융합공학부                                                                                     1
# ai소프트웨어융합학부                                                                                  1
# Name: count, dtype: int64
# ============================================================
# 📌 [major1_2] - 총 종류: 163개
# ------------------------------
# major1_2
# 없음                                  958
# IT(컴퓨터 공학 포함)                       139
# 경영학                                  66
# 자연과학                                 53
# 통계학과                                 23
# 경영학과                                 19
# 사회과학                                 19
# 경제통상학                                18
# 컴퓨터공학과                               16
# 응용통계학과                               13
# 경제학과                                 10
# 경영학부                                  8
# 데이터사이언스학과                             7
# 산업공학과                                 6
# 사회학과                                  6
# 데이터사이언스소프트웨어학과                        5
# 빅데이터융합학과                              5
# 정보통계학과                                5
# 컴퓨터공학부                                5
# 예체능                                   4
# 소프트웨어학과                               4
# 빅데이터분석학과                              4
# 컴퓨터학부                                 4
# 기타                                    4
# 시스템경영공학과                              4
# 소프트웨어학부                               3
# 컴퓨터학과                                 3
# 경제학부                                  3
# 의약학                                   3
# 소비자학과                                 2
# 컴퓨터과학과                                2
# 국제통상학과                                2
# 빅데이터학과                                2
# 인문학                                   2
# 소프트웨어벤처 학과                            2
# 빅데이터응용학과                              2
# 문헌정보학과                                2
# 데이터사이언스융합전공학과                         2
# 융복합소프트웨어학과                            2
# 인공지능학부                                2
# 데이터인포매틱스학과                            1
# AI융합학부                                1
# 산업보안학과                                1
# 생활문화소비자학과                             1
# 연계전공 - 데이터사이언스융합학과                    1
# 식품영양학과                                1
# 교육학                                   1
# 국제통상학전공                               1
# AI융합학과                                1
# Ai학부                                  1
# AI 융합 전공 학과                           1
# 휴먼지능정보공학과                             1
# 정밀의료융합전공학과                            1
# 수리통계데이터사이언스학부 빅데이터학과                  1
# 신소재공학부                                1
# 수학통계학부 응용통계학과                         1
# 커뮤니케이션미디어학부                           1
# 빅데이터 경영학과                             1
# 인공지능반도체공학과                            1
# 인공지능학부 인공지능학과                         1
# 미디어커뮤니케이션학과                           1
# 국제통상연계전공                              1
# 바이오메디컬공학과                             1
# 문화인류학과                                1
# AI 융합학과                               1
# 빅데이터융합전공학과                            1
# 핀테크비지니스 학과                            1
# 데이터 사이언스 소프트웨어 학과                     1
# 물류학과                                  1
# 융합데이터공학과                              1
# AI데이터학부                               1
# 행정정보학과                                1
# 사회과학융합학부                              1
# 경영정보학과                                1
# 국제학부                                  1
# e-비즈니스학과                              1
# 도시사회학과                                1
# 글로벌문화기술학과                             1
# 경영인텔리전스학과                             1
# 통계데이터학과                               1
# AI데이터융합학부                             1
# 전자공학부                                 1
# 기계스마트산업공학부 산업공학과                      1
# 인문학과 사회과학 학부                          1
# AI융합전공학부                              1
# 정치국제학과                                1
# 반도체공학과                                1
# 비즈니스 애널리틱스 학과                         1
# 데이터사이언스연계전공학과                         1
# 빅데이터마이크로전공학과                          1
# 인공지능컴퓨팅학과                             1
# 디자인조형학부                               1
# 국어교육학과                                1
# 데이터사이언스융합학부                           1
# 바이오인포매틱스전공(학과                         1
# 융합에너지공학과                              1
# 산업데이터공학과                              1
# 언어,뇌,컴퓨터 융합 학부                        1
# 생명공학과                                 1
# 융합소프트웨어학과                             1
# 융복합소프트웨어전공학부                          1
# 빅데이터전공학과                              1
# 지역경제개발협력전공학과                          1
# 시각영상디자인학과                             1
# 정치외교학과                                1
# 데이터융합서비스디자인전공[융합전공-학과/학부가 아님] 학부      1
# 응용데이터사이언스학과                           1
# 융합보안학부                                1
# 컴퓨터정보통신공학과                            1
# 융합소프트웨어학부                             1
# 전자전기공학부                               1
# 생명과학과                                 1
# 정보통계보험수리학과                            1
# 경영인텔리젼스학과                             1
# 산업공학학과                                1
# 산업경영공학과                               1
# 수학과                                   1
# 데이터사이언스연계전공 SW학과                      1
# AI빅데이터융합학과                            1
# 심리학과                                  1
# 응용심리학과                                1
# 부동산학과                                 1
# 인지과학학부                                1
# 컴퓨터 전자시스템학부                           1
# sw&AI융합전공학과                           1
# 문화콘텐츠학과                               1
# 공과대학 산업공학부                            1
# 융복합소프트웨어학부                            1
# 바이오나노학과                               1
# 데이터 애널리틱스 학과                          1
# 데이터사이언스융합학과                           1
# 영어교육학과                                1
# 정보시스템학과                               1
# 인공지능인문학과                              1
# 공공거버넌스와리더십학부                          1
# 정밀의료전공(연계)학과                          1
# 금융공학과                                 1
# AI빅데이터융합경영학과                          1
# 스마트팩토리학과                              1
# 홍보광고학과                                1
# 사이버보안학과                               1
# 데이터과학과                                1
# AI 융합학부                               1
# 융복합 소프트웨어학과                           1
# 금융정보공학과                               1
# 데이터사이언스학부                             1
# 검퓨터공학부                                1
# 비즈니스애널리틱스 융합전공학부                      1
# 말레이인도네시아학과                            1
# 빅데이터융합 연계전공 학과                        1
# 인공지능융합학과                              1
# 응용데이터사이언스 학부                          1
# 금융공학융학전공학부                            1
# 인지인공지능학과                              1
# 정보통신융합공학과                             1
# 빅데이터분석학부                              1
# 비즈니스 마케팅 학과                           1
# 데이터사이언스전공학부                           1
# 소비자생활문화산업학과                           1
# 빅데이터 융합학과                             1
# AI융합학부 AI학과                           1
# 융합소프트웨어학부 데이터사이언스학과                   1
# 데이터사이언스 소프트웨어학과                       1
# Name: count, dtype: int64
# ============================================================

# %%
# 전공 매핑 함수 (한글 버전, Unknown/없음 보존)
def map_major_category(major_name):
    # 0. 기존 결측치 처리값 보존 (가장 중요!)
    if pd.isna(major_name): return 'Unknown'
    if major_name == 'Unknown': return 'Unknown'
    if major_name == '없음': return '없음'
    
    # 전처리: 괄호/공백 제거, 소문자 변환
    name = str(major_name).replace(' ', '').replace('(', '').replace(')', '').lower()
    
    # 1. 이공계 (IT / 공학 / 데이터 / 통계)
    it_keywords = [
        '컴퓨터', '소프트웨어', 'sw', 'ai', '인공지능', '데이터', 'data', '정보', '전산', 
        '공학', '산업', '시스템', '기계', '전자', '전기', '통신', '보안', '미디어', 
        '디지털', '융합', '통계', '빅데이터', '로봇', '스마트', 'ict', '반도체', '건축', '토목'
    ]
    if any(k in name for k in it_keywords):
        return '이공계'
    
    # 2. 상경계 (경영, 경제)
    biz_keywords = [
        '경영', '경제', '비즈니스', '금융', '회계', '마케팅', '무역', '통상', 
        '관광', '부동산', '컨벤션', '호텔', '세무', '소비자'
    ]
    if any(k in name for k in biz_keywords):
        return '상경계'
    
    # 3. 자연/의약 (자연과학 / 의약학)
    science_keywords = [
        '수학', '물리', '화학', '생물', '과학', '바이오', '의학', '약학', '간호', 
        '보건', '환경', '식품', '영양', '생명', '의류', '조경', '산림', '농업', '수의'
    ]
    if any(k in name for k in science_keywords):
        return '자연_의약계'
    
    # 4. 인문/사회 (인문 / 사회 / 교육 / 법)
    humanity_keywords = [
        '사회', '심리', '정치', '외교', '언어', '문학', '철학', '사학', '영어', '중국어', 
        '일본어', '프랑스', '독일', '러시아', '아시아', '유럽', '국제', '교육', '법학', 
        '행정', '복지', '문화', '인류', '지리', '신문', '방송', '광고', '홍보', '어문', '역사'
    ]
    if any(k in name for k in humanity_keywords):
        return '인문_사회계'
        
    # 5. 예체능
    art_keywords = ['체육', '스포츠', '미술', '디자인', '음악', '작곡', '연기', '영화', '예술', '무용', '바둑']
    if any(k in name for k in art_keywords):
        return '예체능계'
        
    # 6. 그 외 (매칭 안 된 것들) -> 희소
    return '희소'


print("🚀 전공(major1_1, major1_2) 계열화 작업 및 인코딩 시작")
print("=" * 60)


cols_to_map = ['major1_1', 'major1_2']


for col in cols_to_map:
    if col not in df_all.columns: continue
    
    # 1. 키워드 매핑 적용
    df_all[col] = df_all[col].apply(map_major_category)
    
    # 결과 확인
    print(f"📌 [{col}] 계열화 결과:")
    print(df_all[col].value_counts())
    
    # 2. 인코딩 (★ 수정: dtype=int)
    dummies = pd.get_dummies(df_all[col], prefix=col, dtype=int)
    
    # 컬럼명 확인
    new_cols = dummies.columns.tolist()
    
    # 병합
    df_all = pd.concat([df_all, dummies], axis=1)
    df_all.drop(columns=[col], inplace=True)
    
    print(f"   -> {len(new_cols)}개 변수 생성: {new_cols}")
    print("-" * 30)


print(f"🎉 모든 전처리 완료! 최종 컬럼 수: {df_all.shape[1]}")
# Out:
# 🚀 전공(major1_1, major1_2) 계열화 작업 및 인코딩 시작
# ============================================================
# 📌 [major1_1] 계열화 결과:
# major1_1
# 이공계        721
# 상경계        331
# 자연_의약계     224
# 인문_사회계     144
# Unknown     93
# 희소          44
# 예체능계         5
# Name: count, dtype: int64
#    -> 7개 변수 생성: ['major1_1_Unknown', 'major1_1_상경계', 'major1_1_예체능계', 'major1_1_이공계', 'major1_1_인문_사회계', 'major1_1_자연_의약계', 'major1_1_희소']
# ------------------------------
# 📌 [major1_2] 계열화 결과:
# major1_2
# 없음        958
# 이공계       350
# 상경계       137
# 자연_의약계     81
# 인문_사회계     21
# 희소         13
# 예체능계        2
# Name: count, dtype: int64
#    -> 7개 변수 생성: ['major1_2_상경계', 'major1_2_없음', 'major1_2_예체능계', 'major1_2_이공계', 'major1_2_인문_사회계', 'major1_2_자연_의약계', 'major1_2_희소']
# ------------------------------
# 🎉 모든 전처리 완료! 최종 컬럼 수: 159

# %% [markdown]
# ## 추가한 변수들 전처리

# %% [markdown]
# 범주형
# - previous_class_6
# - previous_class_7
# - previous_class_8
#
# 수치형
# - school1
# - class2

# %% [markdown]
# A. 범주형<br>
# [previous_class_6], [previous_class_7], [previous_class_8]<br>
# 1. 결측치를 ‘Unknown’으로 대체
# 2. 이름에 ‘데이터 분석’이 포함된 카테고리를 모두 ‘0004 : 데이터 분석’으로 통합
# 3. [previous_class_7]: ‘해당없음, 0004 : 데이터 분석 입문반 (머신러닝)’ -> ‘0004 : 데이터 분석’

# %%
# 확인할 다중 선택 변수 목록
target_cols = ['previous_class_6', 'previous_class_7', 'previous_class_8']

print("=" * 60)
print("🔍 다중 선택 변수 '알맹이' 카테고리 분석")
print("=" * 60)

for col in target_cols:
    if col in df_all.columns:
        print(f"\n📌 [{col}]")
        
        # 콤마로 쪼개서 각 알맹이 추출
        tokens = df_all[col].astype(str).str.split(',').explode().str.strip()
        
        # 'nan' 문자열 제거 (NaN이 str로 변환된 것)
        tokens = tokens[tokens != 'nan']
        
        # 알맹이별 빈도수 계산
        token_counts = tokens.value_counts()
        
        print(f"   - 총 알맹이 종류: {len(token_counts)}개")
        print("-" * 60)
        print(token_counts)
        print("=" * 60)
    else:
        print(f"⚠️ {col} 컬럼이 존재하지 않습니다.")
# Out:
# ============================================================
# 🔍 다중 선택 변수 '알맹이' 카테고리 분석
# ============================================================
#
# 📌 [previous_class_6]
#    - 총 알맹이 종류: 9개
# ------------------------------------------------------------
# previous_class_6
# 해당없음                        262
# 0004 : 데이터 분석 입문반 (머신러닝)     12
# 0001 : 파이썬 문법 기초반            12
# 0006 : 데이터 분석 전처리반(판다스)       8
# 0008 : 데이터 분석 모델링반 (ML1)      4
# 0005 : 데이터 분석 입문반 (통계)        2
# 0009 : 데이터 분석 개념반             1
# 0003 : R문법 기초반                1
# 0007 : 데이터 분석 전처리 적용반         1
# Name: count, dtype: int64
# ============================================================
#
# 📌 [previous_class_7]
#    - 총 알맹이 종류: 8개
# ------------------------------------------------------------
# previous_class_7
# 해당없음                        241
# 0001 : 파이썬 문법 기초반            21
# 0006 : 데이터 분석 전처리반(판다스)      13
# 0004 : 데이터 분석 입문반 (머신러닝)     13
# 0002 : SQL 문법 기초반             8
# 0009 : 데이터 분석 개념반             5
# 0005 : 데이터 분석 입문반 (통계)        3
# 0008 : 데이터 분석 모델링반 (ML1)      3
# Name: count, dtype: int64
# ============================================================
#
# 📌 [previous_class_8]
#    - 총 알맹이 종류: 9개
# ------------------------------------------------------------
# previous_class_8
# 해당없음                        137
# 0001 : 파이썬 문법 기초반            41
# 0004 : 데이터 분석 입문반 (머신러닝)     41
# 0006 : 데이터 분석 전처리반(판다스)      28
# 0005 : 데이터 분석 입문반 (통계)       26
# 0002 : SQL 문법 기초반            18
# 0007 : 데이터 분석 전처리 적용반        14
# 0008 : 데이터 분석 모델링반 (ML1)     14
# 0009 : 데이터 분석 개념반             1
# Name: count, dtype: int64
# ============================================================

# %%
# 확인할 변수 목록
target_cols = ['previous_class_6', 'previous_class_7', 'previous_class_8']

print("=" * 60)
print("📊 범주형 변수 카테고리 개수 확인")
print("=" * 60)

for col in target_cols:
    if col in df_all.columns:
        # 카테고리별 개수 계산 (결측치 포함)
        value_counts = df_all[col].value_counts(dropna=False)
        unique_count = df_all[col].nunique(dropna=False)
        
        print(f"\n📌 [{col}]")
        print(f"   - 총 카테고리 종류: {unique_count}개")
        print(f"   - 결측치 포함 여부: {'있음' if df_all[col].isna().sum() > 0 else '없음'}")
        print("-" * 60)
        print(value_counts)
        print("=" * 60)
    else:
        print(f"⚠️ {col} 컬럼이 존재하지 않습니다.")
# Out:
# ============================================================
# 📊 범주형 변수 카테고리 개수 확인
# ============================================================
#
# 📌 [previous_class_6]
#    - 총 카테고리 종류: 11개
#    - 결측치 포함 여부: 있음
# ------------------------------------------------------------
# previous_class_6
# NaN                                            1261
# 해당없음                                            262
# 0004 : 데이터 분석 입문반 (머신러닝)                         11
# 0001 : 파이썬 문법 기초반                                10
# 0006 : 데이터 분석 전처리반(판다스)                           8
# 0008 : 데이터 분석 모델링반 (ML1)                          4
# 0005 : 데이터 분석 입문반 (통계)                            2
# 0009 : 데이터 분석 개념반                                 1
# 0001 : 파이썬 문법 기초반, 0003 : R문법 기초반                 1
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석 입문반 (머신러닝)       1
# 0007 : 데이터 분석 전처리 적용반                             1
# Name: count, dtype: int64
# ============================================================
#
# 📌 [previous_class_7]
#    - 총 카테고리 종류: 14개
#    - 결측치 포함 여부: 있음
# ------------------------------------------------------------
# previous_class_7
# NaN                                                  1261
# 해당없음                                                  240
# 0001 : 파이썬 문법 기초반                                      18
# 0006 : 데이터 분석 전처리반(판다스)                                12
# 0004 : 데이터 분석 입문반 (머신러닝)                               10
# 0002 : SQL 문법 기초반                                       5
# 0009 : 데이터 분석 개념반                                       4
# 0005 : 데이터 분석 입문반 (통계)                                  3
# 0008 : 데이터 분석 모델링반 (ML1)                                3
# 0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반                    2
# 해당없음, 0004 : 데이터 분석 입문반 (머신러닝)                          1
# 0001 : 파이썬 문법 기초반, 0009 : 데이터 분석 개념반                    1
# 0002 : SQL 문법 기초반, 0004 : 데이터 분석 입문반 (머신러닝)             1
# 0004 : 데이터 분석 입문반 (머신러닝), 0006 : 데이터 분석 전처리반(판다스)       1
# Name: count, dtype: int64
# ============================================================
#
# 📌 [previous_class_8]
#    - 총 카테고리 종류: 17개
#    - 결측치 포함 여부: 있음
# ------------------------------------------------------------
# previous_class_8
# NaN                                                  1261
# 해당없음                                                  137
# 0001 : 파이썬 문법 기초반                                      34
# 0004 : 데이터 분석 입문반 (머신러닝)                               31
# 0006 : 데이터 분석 전처리반(판다스)                                21
# 0005 : 데이터 분석 입문반 (통계)                                 19
# 0007 : 데이터 분석 전처리 적용반                                  14
# 0008 : 데이터 분석 모델링반 (ML1)                               14
# 0002 : SQL 문법 기초반                                      12
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석 입문반 (머신러닝)             4
# 0004 : 데이터 분석 입문반 (머신러닝), 0005 : 데이터 분석 입문반 (통계)        4
# 0002 : SQL 문법 기초반, 0006 : 데이터 분석 전처리반(판다스)              3
# 0005 : 데이터 분석 입문반 (통계), 0006 : 데이터 분석 전처리반(판다스)         2
# 0004 : 데이터 분석 입문반 (머신러닝), 0006 : 데이터 분석 전처리반(판다스)       2
# 0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반                    2
# 0001 : 파이썬 문법 기초반, 0009 : 데이터 분석 개념반                    1
# 0002 : SQL 문법 기초반, 0005 : 데이터 분석 입문반 (통계)               1
# Name: count, dtype: int64
# ============================================================

# %%
# 처리 대상 변수
target_cols = ['previous_class_6', 'previous_class_7', 'previous_class_8']

# 전체 출력 옵션 설정
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

print("=" * 70)
print("🚀 previous_class 변수 전처리 시작 (전체 카테고리 출력)")
print("=" * 70)

for col in target_cols:
    if col in df_all.columns:
        print(f"\n{'='*70}")
        print(f"📌 [{col}] 처리 중...")
        print('='*70)
        
        # [처리 전] 상태 확인 - 전체 출력
        print(f"\n[처리 전] 모든 카테고리 종류")
        before_counts = df_all[col].value_counts(dropna=False)
        print(f"총 {len(before_counts)}개 카테고리:")
        print(before_counts)
        
        # --------------------------------------------------------
        # 1단계: 결측치를 'Unknown'으로 대체
        # --------------------------------------------------------
        df_all[col] = df_all[col].fillna('Unknown')
        print(f"\n✅ 1단계: 결측치를 'Unknown'으로 대체 완료")
        
        # --------------------------------------------------------
        # 2단계: '해당없음, XXX' 형태의 이상치 처리
        # --------------------------------------------------------
        def clean_해당없음_pattern(text):
            if pd.isna(text) or text == 'Unknown':
                return text
            
            # 콤마로 쪼개기
            parts = [p.strip() for p in str(text).split(',')]
            
            # '해당없음' 제거 (다른 값과 함께 있을 때만)
            if len(parts) > 1 and '해당없음' in parts:
                parts = [p for p in parts if p != '해당없음']
            
            # 다시 합치기 (콤마 뒤 공백 유지)
            return ', '.join(parts) if parts else text
        
        df_all[col] = df_all[col].apply(clean_해당없음_pattern)
        print(f"✅ 2단계: '해당없음, XXX' 이상치 패턴 정리 완료")
        
        # --------------------------------------------------------
        # 3단계: '데이터 분석' 포함 카테고리 통합
        # --------------------------------------------------------
        def consolidate_data_analysis(text):
            if pd.isna(text) or text in ['Unknown', '해당없음']:
                return text
            
            # 콤마로 쪼개기
            parts = [p.strip() for p in str(text).split(',')]
            
            # 각 알맹이 처리
            new_parts = []
            for part in parts:
                # '데이터 분석'이 포함되어 있으면 통합
                if '데이터 분석' in part:
                    new_parts.append('0004 : 데이터 분석')
                else:
                    # 그 외는 그대로 유지
                    new_parts.append(part)
            
            # 중복 제거 및 정렬
            new_parts = sorted(list(set(new_parts)))
            
            # 다시 합치기 (콤마 뒤 공백 유지)
            return ', '.join(new_parts)
        
        df_all[col] = df_all[col].apply(consolidate_data_analysis)
        print(f"✅ 3단계: '데이터 분석' 포함 카테고리를 '0004 : 데이터 분석'으로 통합 완료")
        
        # [처리 후] 상태 확인 - 전체 출력
        print(f"\n[처리 후] 모든 카테고리 종류")
        after_counts = df_all[col].value_counts(dropna=False)
        print(f"총 {len(after_counts)}개 카테고리:")
        print(after_counts)
        
        # 알맹이 확인
        print(f"\n[알맹이 확인]")
        tokens = df_all[col].astype(str).str.split(',').explode().str.strip()
        token_counts = tokens.value_counts()
        print(f"   - 총 알맹이 종류: {len(token_counts)}개")
        print(token_counts)


print("\n" + "=" * 70)
print("🎉 전처리 완료!")
print(f"   - 현재 데이터 shape: {df_all.shape}")
print("=" * 70)


# 옵션 리셋
pd.reset_option('display.max_rows')
pd.reset_option('display.max_colwidth')


# =========================================================
# previous_class 변수 인코딩 (다중 선택 변수)
# =========================================================
print("\n" + "=" * 70)
print("🚀 previous_class 변수 인코딩 및 검증 시작")
print("=" * 70)

# (1) 인코딩 전 원본 백업 (검증용)
for col in target_cols:
    if col in df_all.columns:
        df_all[f'{col}_raw'] = df_all[col]

# (2) 인코딩 수행
for col in target_cols:
    if col in df_all.columns:
        print(f"\n📌 [{col}] 인코딩 중...")
        
        # 다중 선택 변수이므로 get_dummies 사용 (콤마 구분자)
        dummies = df_all[col].str.get_dummies(sep=', ').astype(int)
        
        # 컬럼명에 prefix 추가
        dummies = dummies.add_prefix(f"{col}_")
        
        # 생성된 컬럼 확인
        new_cols = dummies.columns.tolist()
        print(f"   -> {len(new_cols)}개 변수 생성: {new_cols}")
        
        # 원본 데이터에 병합
        df_all = pd.concat([df_all, dummies], axis=1)
        
        # 원본 컬럼 삭제 (백업인 _raw는 남겨둠)
        df_all = df_all.drop(columns=[col])
        
        print(f"   ✅ [{col}] 인코딩 완료 및 원본 컬럼 삭제")

# (3) 인코딩 결과 검증 (질문하신 내용 직접 확인)
print("\n" + "=" * 70)
print("🔍 인코딩 결과 육안 검증 (다중 선택 데이터)")
print("=" * 70)

check_col = 'previous_class_7'
raw_col = f'{check_col}_raw'
prefix = f'{check_col}_'
encoded_cols = [c for c in df_all.columns if c.startswith(prefix)]

# 다중 선택(콤마 포함)인 행 찾기
multi_mask = df_all[raw_col].astype(str).str.contains(',', na=False)
multi_samples = df_all[multi_mask]

if len(multi_samples) > 0:
    print(f"📌 [{check_col}] 다중 선택 데이터 샘플 확인")
    print("-" * 70)
    
    # 보고 싶은 컬럼들만 추려서 출력 (원본 + 인코딩된 컬럼들)
    display_cols = [raw_col] + encoded_cols
    
    # 최대 10개만 출력
    print(multi_samples[display_cols].head(10))
    print("-" * 70)
    print("✅ 위 표에서 원본(_raw)의 값에 해당하는 컬럼이 1이고, 나머지가 0인지 확인하세요.")
else:
    print("⚠️ 다중 선택 데이터가 없습니다.")

print("\n" + "=" * 70)
print("🎉 모든 작업 완료!")
print(f"   - 최종 데이터 shape: {df_all.shape}")
print("=" * 70)
# Out:
# ======================================================================
# 🚀 previous_class 변수 전처리 시작 (전체 카테고리 출력)
# ======================================================================
#
# ======================================================================
# 📌 [previous_class_6] 처리 중...
# ======================================================================
#
# [처리 전] 모든 카테고리 종류
# 총 11개 카테고리:
# previous_class_6
# NaN                                            1261
# 해당없음                                            262
# 0004 : 데이터 분석 입문반 (머신러닝)                         11
# 0001 : 파이썬 문법 기초반                                10
# 0006 : 데이터 분석 전처리반(판다스)                           8
# 0008 : 데이터 분석 모델링반 (ML1)                          4
# 0005 : 데이터 분석 입문반 (통계)                            2
# 0009 : 데이터 분석 개념반                                 1
# 0001 : 파이썬 문법 기초반, 0003 : R문법 기초반                 1
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석 입문반 (머신러닝)       1
# 0007 : 데이터 분석 전처리 적용반                             1
# Name: count, dtype: int64
#
# ✅ 1단계: 결측치를 'Unknown'으로 대체 완료
# ✅ 2단계: '해당없음, XXX' 이상치 패턴 정리 완료
# ✅ 3단계: '데이터 분석' 포함 카테고리를 '0004 : 데이터 분석'으로 통합 완료
#
# [처리 후] 모든 카테고리 종류
# 총 6개 카테고리:
# previous_class_6
# Unknown                              1261
# 해당없음                                  262
# 0004 : 데이터 분석                          27
# 0001 : 파이썬 문법 기초반                      10
# 0001 : 파이썬 문법 기초반, 0003 : R문법 기초반       1
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석        1
# Name: count, dtype: int64
#
# [알맹이 확인]
#    - 총 알맹이 종류: 5개
# previous_class_6
# Unknown              1261
# 해당없음                  262
# 0004 : 데이터 분석          28
# 0001 : 파이썬 문법 기초반      12
# 0003 : R문법 기초반          1
# Name: count, dtype: int64
#
# ======================================================================
# 📌 [previous_class_7] 처리 중...
# ======================================================================
#
# [처리 전] 모든 카테고리 종류
# 총 14개 카테고리:
# previous_class_7
# NaN                                                  1261
# 해당없음                                                  240
# 0001 : 파이썬 문법 기초반                                      18
# 0006 : 데이터 분석 전처리반(판다스)                                12
# 0004 : 데이터 분석 입문반 (머신러닝)                               10
# 0002 : SQL 문법 기초반                                       5
# 0009 : 데이터 분석 개념반                                       4
# 0005 : 데이터 분석 입문반 (통계)                                  3
# 0008 : 데이터 분석 모델링반 (ML1)                                3
# 0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반                    2
# 해당없음, 0004 : 데이터 분석 입문반 (머신러닝)                          1
# 0001 : 파이썬 문법 기초반, 0009 : 데이터 분석 개념반                    1
# 0002 : SQL 문법 기초반, 0004 : 데이터 분석 입문반 (머신러닝)             1
# 0004 : 데이터 분석 입문반 (머신러닝), 0006 : 데이터 분석 전처리반(판다스)       1
# Name: count, dtype: int64
#
# ✅ 1단계: 결측치를 'Unknown'으로 대체 완료
# ✅ 2단계: '해당없음, XXX' 이상치 패턴 정리 완료
# ✅ 3단계: '데이터 분석' 포함 카테고리를 '0004 : 데이터 분석'으로 통합 완료
#
# [처리 후] 모든 카테고리 종류
# 총 8개 카테고리:
# previous_class_7
# Unknown                                 1261
# 해당없음                                     240
# 0004 : 데이터 분석                             34
# 0001 : 파이썬 문법 기초반                         18
# 0002 : SQL 문법 기초반                          5
# 0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반       2
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석           1
# 0002 : SQL 문법 기초반, 0004 : 데이터 분석           1
# Name: count, dtype: int64
#
# [알맹이 확인]
#    - 총 알맹이 종류: 5개
# previous_class_7
# Unknown              1261
# 해당없음                  240
# 0004 : 데이터 분석          36
# 0001 : 파이썬 문법 기초반      21
# 0002 : SQL 문법 기초반       8
# Name: count, dtype: int64
#
# ======================================================================
# 📌 [previous_class_8] 처리 중...
# ======================================================================
#
# [처리 전] 모든 카테고리 종류
# 총 17개 카테고리:
# previous_class_8
# NaN                                                  1261
# 해당없음                                                  137
# 0001 : 파이썬 문법 기초반                                      34
# 0004 : 데이터 분석 입문반 (머신러닝)                               31
# 0006 : 데이터 분석 전처리반(판다스)                                21
# 0005 : 데이터 분석 입문반 (통계)                                 19
# 0007 : 데이터 분석 전처리 적용반                                  14
# 0008 : 데이터 분석 모델링반 (ML1)                               14
# 0002 : SQL 문법 기초반                                      12
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석 입문반 (머신러닝)             4
# 0004 : 데이터 분석 입문반 (머신러닝), 0005 : 데이터 분석 입문반 (통계)        4
# 0002 : SQL 문법 기초반, 0006 : 데이터 분석 전처리반(판다스)              3
# 0005 : 데이터 분석 입문반 (통계), 0006 : 데이터 분석 전처리반(판다스)         2
# 0004 : 데이터 분석 입문반 (머신러닝), 0006 : 데이터 분석 전처리반(판다스)       2
# 0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반                    2
# 0001 : 파이썬 문법 기초반, 0009 : 데이터 분석 개념반                    1
# 0002 : SQL 문법 기초반, 0005 : 데이터 분석 입문반 (통계)               1
# Name: count, dtype: int64
#
# ✅ 1단계: 결측치를 'Unknown'으로 대체 완료
# ✅ 2단계: '해당없음, XXX' 이상치 패턴 정리 완료
# ✅ 3단계: '데이터 분석' 포함 카테고리를 '0004 : 데이터 분석'으로 통합 완료
#
# [처리 후] 모든 카테고리 종류
# 총 8개 카테고리:
# previous_class_8
# Unknown                                 1261
# 해당없음                                     137
# 0004 : 데이터 분석                            107
# 0001 : 파이썬 문법 기초반                         34
# 0002 : SQL 문법 기초반                         12
# 0001 : 파이썬 문법 기초반, 0004 : 데이터 분석           5
# 0002 : SQL 문법 기초반, 0004 : 데이터 분석           4
# 0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반       2
# Name: count, dtype: int64
#
# [알맹이 확인]
#    - 총 알맹이 종류: 5개
# previous_class_8
# Unknown              1261
# 해당없음                  137
# 0004 : 데이터 분석         116
# 0001 : 파이썬 문법 기초반      41
# 0002 : SQL 문법 기초반      18
# Name: count, dtype: int64
#
# ======================================================================
# 🎉 전처리 완료!
#    - 현재 데이터 shape: (1562, 159)
# ======================================================================
#
# ======================================================================
# 🚀 previous_class 변수 인코딩 및 검증 시작
# ======================================================================
#
# 📌 [previous_class_6] 인코딩 중...
#    -> 5개 변수 생성: ['previous_class_6_0001 : 파이썬 문법 기초반', 'previous_class_6_0003 : R문법 기초반', 'previous_class_6_0004 : 데이터 분석', 'previous_class_6_Unknown', 'previous_class_6_해당없음']
#    ✅ [previous_class_6] 인코딩 완료 및 원본 컬럼 삭제
#
# 📌 [previous_class_7] 인코딩 중...
#    -> 5개 변수 생성: ['previous_class_7_0001 : 파이썬 문법 기초반', 'previous_class_7_0002 : SQL 문법 기초반', 'previous_class_7_0004 : 데이터 분석', 'previous_class_7_Unknown', 'previous_class_7_해당없음']
#    ✅ [previous_class_7] 인코딩 완료 및 원본 컬럼 삭제
#
# 📌 [previous_class_8] 인코딩 중...
#    -> 5개 변수 생성: ['previous_class_8_0001 : 파이썬 문법 기초반', 'previous_class_8_0002 : SQL 문법 기초반', 'previous_class_8_0004 : 데이터 분석', 'previous_class_8_Unknown', 'previous_class_8_해당없음']
#    ✅ [previous_class_8] 인코딩 완료 및 원본 컬럼 삭제
#
# ======================================================================
# 🔍 인코딩 결과 육안 검증 (다중 선택 데이터)
# ======================================================================
# 📌 [previous_class_7] 다중 선택 데이터 샘플 확인
# ----------------------------------------------------------------------
#                       previous_class_7_raw  \
# 456   0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반
# 532       0001 : 파이썬 문법 기초반, 0004 : 데이터 분석
# 657       0002 : SQL 문법 기초반, 0004 : 데이터 분석
# 1339  0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반
#
#                       previous_class_7_raw  \
# 456   0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반
# 532       0001 : 파이썬 문법 기초반, 0004 : 데이터 분석
# 657       0002 : SQL 문법 기초반, 0004 : 데이터 분석
# 1339  0001 : 파이썬 문법 기초반, 0002 : SQL 문법 기초반
#
#       previous_class_7_0001 : 파이썬 문법 기초반  previous_class_7_0002 : SQL 문법 기초반  \
# 456                                    1                                   1
# 532                                    1                                   0
# 657                                    0                                   1
# 1339                                   1                                   1
#
#       previous_class_7_0004 : 데이터 분석  previous_class_7_Unknown  \
# 456                                0                         0
# 532                                1                         0
# 657                                1                         0
# 1339                               0                         0
#
#       previous_class_7_해당없음
# 456                       0
# 532                       0
# 657                       0
# 1339                      0
# ----------------------------------------------------------------------
# ✅ 위 표에서 원본(_raw)의 값에 해당하는 컬럼이 1이고, 나머지가 0인지 확인하세요.
#
# ======================================================================
# 🎉 모든 작업 완료!
#    - 최종 데이터 shape: (1562, 174)
# ======================================================================

# %% [markdown]
# B. 수치형<br>
# [school1]<br>
# 카테고리가 99개로 너무 많음 -> 타겟 인코딩(스무딩 적용)
#
# [class2]<br>
# 결측치를 'Unknown'으로 대체<br>
# 데이터 타입을 실수형 -> 정수형 -> 범주형으로 변환 후 원-핫 인코딩

# %%
# school1 피처 확인
col = 'school1'

if col in df_all.columns:
    print(f"📌 [{col}] 카테고리 분석")
    print("-" * 50)
    
    # 1. 고유값 개수 (NaN 포함 여부 확인)
    n_unique = df_all[col].nunique(dropna=False)
    print(f"총 카테고리 개수: {n_unique}개")
    
    # 2. 카테고리별 빈도수 (전체 출력)
    print("\n[값별 빈도수]")
    print(df_all[col].value_counts(dropna=False))
else:
    print(f"⚠️ 데이터프레임에 '{col}' 컬럼이 없습니다.")
# Out:
# 📌 [school1] 카테고리 분석
# --------------------------------------------------
# 총 카테고리 개수: 99개
#
# [값별 빈도수]
# school1
# 0     97
# 11    84
# 24    72
# 16    67
# 20    63
#       ..
# 12     1
# 92     1
# 43     1
# 97     1
# 96     1
# Name: count, Length: 99, dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold

# =========================================================
# school1 변수 타겟 인코딩 (K-Fold OOF 적용으로 Leakage 완벽 차단)
# =========================================================

# 1. 설정
target_col_name = 'completed'   # ★ 타겟 변수명
encode_col = 'school1'
m_smoothing = 10  # 스무딩 강도
n_folds = 5       # K-Fold 개수 (보통 5 사용)
seed = 42         # 재현성을 위한 시드

print("\n" + "=" * 70)
print(f"🚀 [{encode_col}] K-Fold 타겟 인코딩 시작 (Target: {target_col_name})")
print(f"   - Train: 5-Fold OOF 방식 (자기 자신 정답 참조 방지)")
print(f"   - Test : Train 전체 통계 적용 (기존 방식 유지)")
print("=" * 70)

if encode_col in df_all.columns and target_col_name in df_all.columns:
    
    # -----------------------------------------------------
    # (1) 데이터 분리
    # -----------------------------------------------------
    train_indices = df_all[df_all['dataset'] == 'train'].index
    test_indices = df_all[df_all['dataset'] == 'test'].index
    
    # 원본 보존을 위해 복사본 생성 (SettingWithCopyWarning 방지)
    train_df = df_all.loc[train_indices].copy()
    test_df = df_all.loc[test_indices].copy()
    
    # 결과 담을 컬럼 초기화
    new_col_name = f'{encode_col}_target_enc'
    df_all[new_col_name] = np.nan  # 일단 비워둠

    # -----------------------------------------------------
    # (2) [TRAIN] K-Fold OOF 인코딩 (학습 데이터 내부 과적합 방지)
    # -----------------------------------------------------
    kf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)
    
    # 진행 상황 출력을 위한 카운터
    fold_cnt = 1
    
    for tr_idx, val_idx in kf.split(train_df, train_df[target_col_name]):
        # tr_idx: 학습에 쓸 데이터 (남의 조)
        # val_idx: 점수를 채울 데이터 (우리 조)
        
        X_tr, X_val = train_df.iloc[tr_idx], train_df.iloc[val_idx]
        
        # [남의 조] 통계 계산
        fold_global_mean = X_tr[target_col_name].mean()
        fold_agg = X_tr.groupby(encode_col)[target_col_name].agg(['count', 'mean'])
        
        # [남의 조] 스무딩 점수 계산
        fold_smooth = (fold_agg['count'] * fold_agg['mean'] + m_smoothing * fold_global_mean) / (fold_agg['count'] + m_smoothing)
        
        # [우리 조]에 매핑 (없는 학교는 fold_global_mean으로 채움)
        # 주의: X_val의 원래 인덱스를 사용하여 df_all에 직접 업데이트
        mapped_values = X_val[encode_col].map(fold_smooth).fillna(fold_global_mean)
        df_all.loc[X_val.index, new_col_name] = mapped_values
        
        fold_cnt += 1

    print(f"✅ Train 데이터 K-Fold ({n_folds}분할) 인코딩 완료")

    # -----------------------------------------------------
    # (3) [TEST] 전체 Train 통계 적용 (기존과 동일)
    # -----------------------------------------------------
    # Train 전체 기준 통계 계산
    global_mean = train_df[target_col_name].mean()
    agg_global = train_df.groupby(encode_col)[target_col_name].agg(['count', 'mean'])
    
    # Train 전체 스무딩 점수
    smooth_score_global = (agg_global['count'] * agg_global['mean'] + m_smoothing * global_mean) / (agg_global['count'] + m_smoothing)
    
    # Test 데이터 매핑
    test_mapped = test_df[encode_col].map(smooth_score_global).fillna(global_mean)
    df_all.loc[test_indices, new_col_name] = test_mapped
    
    print(f"✅ Test 데이터 전체 통계 매핑 완료")
    
    # -----------------------------------------------------
    # (4) 마무리
    # -----------------------------------------------------
    # 원본 컬럼 삭제
    df_all.drop(columns=[encode_col], inplace=True)
    
    print("-" * 50)
    print(f"📌 [결과 확인] 변환된 컬럼: {new_col_name}")
    print(f"   - Train 결측치 수: {df_all.loc[train_indices, new_col_name].isna().sum()}")
    print(f"   - Test 결측치 수 : {df_all.loc[test_indices, new_col_name].isna().sum()}")
    print("-" * 50)
    print("👀 [데이터 미리보기 (Train 상위 5행)] - OOF 값이라 같은 학교라도 점수가 미세하게 다를 수 있음")
    print(df_all.loc[train_indices, ['dataset', new_col_name]].head())
    
else:
    print(f"🚨 오류: '{encode_col}' 또는 '{target_col_name}' 컬럼이 데이터프레임에 없습니다.")
    print("   - 타겟 변수명이 'completed'가 맞는지 확인해주세요.")


# ---------------------------------------------------------
# [검증] 단순 통계 vs OOF 인코딩 값 비교
# ---------------------------------------------------------

# 검증을 위해 'Train 전체 기준' 통계 다시 가져옴 (위의 smooth_score_global 활용)
result_df = pd.DataFrame({
    '전체 학생 수': agg_global['count'],
    '수료자 수': (agg_global['count'] * agg_global['mean']).astype(int),
    '단순 수료율': agg_global['mean'],
    '전체기준 스무딩 점수': smooth_score_global
})

print("\n📌 [상세 확인] (참고용) Train 전체 기준 학교별 점수 Top 5")
print("   * 주의: 실제 Train 데이터에는 이 점수가 아니라, Fold별로 계산된 점수가 들어갔습니다.")
print("=" * 70)
print(result_df.sort_values(by='전체기준 스무딩 점수', ascending=False).head(5))
print("-" * 70)

# 불필요하게 남은 검증용 백업 컬럼 삭제 로직 유지
cols_to_drop = ['previous_class_6_raw', 'previous_class_7_raw', 'previous_class_8_raw']
real_drop = [c for c in cols_to_drop if c in df_all.columns]
df_all = df_all.drop(columns=real_drop)

print(f"🗑️ 검증용 임시 변수 {len(real_drop)}개 삭제 완료: {real_drop}")
print(f"📊 현재 남은 object 변수: {df_all.select_dtypes(include='object').columns.tolist()}")
# Out:
# ======================================================================
# 🚀 [school1] K-Fold 타겟 인코딩 시작 (Target: completed)
#    - Train: 5-Fold OOF 방식 (자기 자신 정답 참조 방지)
#    - Test : Train 전체 통계 적용 (기존 방식 유지)
# ======================================================================
# ✅ Train 데이터 K-Fold (5분할) 인코딩 완료
# ✅ Test 데이터 전체 통계 매핑 완료
# --------------------------------------------------
# 📌 [결과 확인] 변환된 컬럼: school1_target_enc
#    - Train 결측치 수: 0
#    - Test 결측치 수 : 0
# --------------------------------------------------
# 👀 [데이터 미리보기 (Train 상위 5행)] - OOF 값이라 같은 학교라도 점수가 미세하게 다를 수 있음
#   dataset  school1_target_enc
# 0   train            0.296665
# 1   train            0.332944
# 2   train            0.350719
# 3   train            0.332624
# 4   train            0.393230
#
# 📌 [상세 확인] (참고용) Train 전체 기준 학교별 점수 Top 5
#    * 주의: 실제 Train 데이터에는 이 점수가 아니라, Fold별로 계산된 점수가 들어갔습니다.
# ======================================================================
#          전체 학생 수  수료자 수    단순 수료율  전체기준 스무딩 점수
# school1
# 45             5      4  0.800000     0.465419
# 38            17      9  0.529412     0.443751
# 63             2      2  1.000000     0.415107
# 70             2      2  1.000000     0.415107
# 24            35     15  0.428571     0.399584
# ----------------------------------------------------------------------
# 🗑️ 검증용 임시 변수 3개 삭제 완료: ['previous_class_6_raw', 'previous_class_7_raw', 'previous_class_8_raw']
# 📊 현재 남은 object 변수: ['dataset']

# %%
# class2 피처 확인 (범주형 변환 후)
col = 'class2'

if col in df_all.columns:
    print(f"📌 [{col}] 카테고리 분석")
    print("-" * 50)
    
    # 1. 범주형(문자열)으로 변환
    # (원본 데이터프레임에 반영하지 않고, 확인용 임시 시리즈 생성)
    temp_series = df_all[col].astype(str)
    
    # 2. 고유값 개수
    n_unique = temp_series.nunique(dropna=False)
    print(f"총 카테고리 개수: {n_unique}개")
    
    # 3. 카테고리별 빈도수 (전체 출력)
    print("\n[값별 빈도수]")
    # dropna=False: 결측치(NaN)도 'nan'이라는 문자로 변환되어 카운트됨
    print(temp_series.value_counts(dropna=False))
    
else:
    print(f"⚠️ 데이터프레임에 '{col}' 컬럼이 없습니다.")
# Out:
# 📌 [class2] 카테고리 분석
# --------------------------------------------------
# 총 카테고리 개수: 13개
#
# [값별 빈도수]
# class2
# nan     1151
# 5.0       90
# 2.0       71
# 4.0       50
# 6.0       43
# 8.0       41
# 15.0      29
# 12.0      27
# 7.0       16
# 13.0      13
# 16.0      12
# 11.0      10
# 14.0       9
# Name: count, dtype: int64

# %%
col = 'class2'

if col in df_all.columns:
    print(f"🚀 [{col}] 전처리 및 원-핫 인코딩 시작")
    print("=" * 60)
    
    # ---------------------------------------------------------
    # 1. 결측치 처리 & 타입 변환 (소수점 제거)
    # ---------------------------------------------------------
    
    # (1) NaN을 유지한 채로 정수형('Int64') 변환 -> 문자열 변환
    #     이렇게 하면 5.0 -> 5 -> "5"가 되고, NaN -> <NA> -> "<NA>"가 됩니다.
    temp = df_all[col].astype('Int64').astype(str)
    
    # (2) "<NA>" 문자열을 'Unknown'으로 치환
    df_all[col] = temp.replace('<NA>', 'Unknown')
    
    print(f"✅ 결측치 'Unknown' 대체 및 소수점 제거 완료")
    print(f"   - 카테고리 종류: {df_all[col].unique()}")
    
    # ---------------------------------------------------------
    # 2. 원-핫 인코딩 (One-Hot Encoding)
    # ---------------------------------------------------------
    # prefix: 생성될 컬럼 앞에 붙을 접두사 (예: class2_5, class2_Unknown)
    dummies = pd.get_dummies(df_all[col], prefix=col, dtype=int)
    
    # 원본 데이터와 병합
    df_all = pd.concat([df_all, dummies], axis=1)
    
    # 원본 컬럼 삭제
    df_all.drop(columns=[col], inplace=True)
    
    # 결과 확인
    new_cols = dummies.columns.tolist()
    print(f"✅ 원-핫 인코딩 완료")
    print(f"   - 생성된 컬럼 ({len(new_cols)}개): {new_cols}")
    print("-" * 60)
    
    # 데이터 미리보기 (dataset 컬럼 포함해서 확인)
    display_cols = ['dataset'] + new_cols[:5] # 앞부분 5개만 확인
    print("👀 [데이터 미리보기]")
    print(df_all[display_cols].head())

else:
    print(f"🚨 데이터프레임에 '{col}' 컬럼이 없습니다.")

print("=" * 60)
# Out:
# 🚀 [class2] 전처리 및 원-핫 인코딩 시작
# ============================================================
# ✅ 결측치 'Unknown' 대체 및 소수점 제거 완료
#    - 카테고리 종류: ['4' 'Unknown' '6' '5' '2' '8' '13' '11' '12' '7' '15' '16' '14']
# ✅ 원-핫 인코딩 완료
#    - 생성된 컬럼 (13개): ['class2_11', 'class2_12', 'class2_13', 'class2_14', 'class2_15', 'class2_16', 'class2_2', 'class2_4', 'class2_5', 'class2_6', 'class2_7', 'class2_8', 'class2_Unknown']
# ------------------------------------------------------------
# 👀 [데이터 미리보기]
#   dataset  class2_11  class2_12  class2_13  class2_14  class2_15
# 0   train          0          0          0          0          0
# 1   train          0          0          0          0          0
# 2   train          0          0          0          0          0
# 3   train          0          0          0          0          0
# 4   train          0          0          0          0          0
# ============================================================

# %% [markdown]
# # EDA

# %%
# 타겟 변수 분포 확인
print("타겟 변수 분포:")
print(train['completed'].value_counts())
print("\n비율:")
print(train['completed'].value_counts(normalize=True))

# 불균형 비율 계산
majority = train['completed'].value_counts().iloc[0]
minority = train['completed'].value_counts().iloc[1]
IR = majority / minority
print(f"\n클래스 불균형 비율(IR): {IR:.2f}")
# Out:
# 타겟 변수 분포:
# completed
# 0    525
# 1    223
# Name: count, dtype: int64
#
# 비율:
# completed
# 0    0.701872
# 1    0.298128
# Name: proportion, dtype: float64
#
# 클래스 불균형 비율(IR): 2.35

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# 1. 중요도 분석을 위한 임시 학습 데이터셋 정의
# (df_all을 훼손하지 않고, 정답(completed)이 있는 train 데이터만 슬라이싱하여 사용)
train_subset = df_all[df_all['dataset'] == 'train'].copy()

# 2. 불필요한 컬럼 제외 (dataset, ID 등 식별자, 타겟 변수)
# 사용자가 삭제하지 않은 ID나 기타 object 컬럼이 있다면 여기서 drop에 추가해야 에러가 안 납니다.
X_temp = train_subset.drop(columns=['completed', 'dataset']) 
y_temp = train_subset['completed']

# 3. 모델 학습 (가볍게 100그루만)
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
rf.fit(X_temp, y_temp)

# 4. 중요도 추출 및 정렬
importances = pd.Series(rf.feature_importances_, index=X_temp.columns)
top30_features = importances.sort_values(ascending=False).head(30)

# 5. 시각화
plt.figure(figsize=(10, 12))
sns.barplot(x=top30_features.values, y=top30_features.index)
plt.title('Top 30 Feature Importance (Random Forest)')
plt.xlabel('Importance Score')
plt.show()

# 텍스트로도 출력
print("=== Top 30 Features ===")
print(top30_features)
# Out:
# === Top 30 Features ===
# school1_target_enc                                        0.055676
# completed_semester                                        0.027112
# time_input                                                0.023883
# hope_for_group_네. 온라인으로 참여하고 싶어요                          0.012667
# certificate_acquisition_SQLD                              0.012373
# desired_job_C. 데이터 사이언티스트                                 0.011753
# onedayclass_topic_Python 응용                               0.011483
# hope_for_group_네. 오프라인으로 참여하고 싶어요                         0.011198
# desired_job_except_data_B. 기획 / 전략 / 경영 직무                0.011127
# desired_certificate_정보처리기사                                0.011038
# onedayclass_topic_데이터 시각화 (Matplotlib, Seaborn 등)         0.011029
# desired_job_except_data_F. PM / 서비스 기획자                   0.010956
# major_data                                                0.010918
# onedayclass_topic_SQL 응용                                  0.010878
# incumbents_level                                          0.010645
# major1_2_이공계                                              0.010557
# incumbents_company_level_국내 대기업 IT 계열 (금융, 제조 ...)        0.010519
# desired_job_B. 데이터 분석가                                    0.010458
# incumbents_company_level_국내 빅테크 IT 계열 (네카라쿠배당토)           0.010443
# certificate_acquisition_없음                                0.010409
# expected_domain_K. 금융 및 보험업                               0.010323
# incumbents_lecture_직무 강의 (예시: 실무 진행 방식 및 직무 준비생을 위한 팁)    0.010321
# desired_job_except_data_D. 소프트웨어 개발자                      0.010250
# major_field_이공계                                           0.010186
# class2_Unknown                                            0.010066
# incumbents_lecture_scale_3~50명 내외의 강의 리스너와 1명의 현직자        0.010003
# expected_domain_J. 정보통신업                                  0.009966
# desired_certificate_SQLD                                  0.009941
# what_to_gain_데이터 분석 역량                                    0.009727
# incumbents_lecture_type_온라인                               0.009583
# dtype: float64

# %%
# df_all은 너무 크고 test데이터는 정답이 없으니, X_temp(train의 feature들) 사용
# 상관계수 행렬 계산
corr_mat = X_temp.corr().abs()

# 대각선 위쪽만 선택 (중복 제거)
upper = corr_mat.where(np.triu(np.ones(corr_mat.shape), k=1).astype(bool))

# 상관계수가 0.95보다 큰 변수 찾기
high_corr_cols = [column for column in upper.columns if any(upper[column] > 0.95)]

print(f"다중공선성 의심 변수 ({len(high_corr_cols)}개):")
print(high_corr_cols)
# Out:
# 다중공선성 의심 변수 (5개):
# ['inflow_route_기존 학회원 또는 운영진', 'whyBDA_이전 기수에 매우 만족해서', 'previous_class_6_Unknown', 'previous_class_7_Unknown', 'previous_class_8_Unknown']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 주의: 앞선 코드에서 df_all의 'school1' 원본 컬럼을 drop 했다면, 
# 원본 train 데이터를 다시 불러오거나 백업된 데이터를 사용해야 합니다.
# 여기서는 train 변수(원본)가 메모리에 있다고 가정하고 코드를 작성합니다.

# 1. 검증용 데이터프레임 생성 (학교별 수치 계산)
# train 데이터만 사용해야 정확한 '학습 시점'의 왜곡을 볼 수 있습니다.
school_stats = train.groupby('school1').agg(
    student_count=('completed', 'count'),       # 학교별 학생 수
    mean_completed=('completed', 'mean')        # 단순 수료율
).reset_index()

# 2. df_all에 있는 'school1_target_enc' 값을 가져오기 위해 매핑
# (학교명이 같은 행 하나씩만 뽑아서 매핑 테이블 생성)
mapping_table = df_all[df_all['dataset']=='train'][['school1_target_enc']].copy()
# df_all에는 school1 원본이 없으므로, train의 인덱스와 매칭하거나 
# 만약 df_all에 school1 원본을 남겨뒀다면 바로 groupby 하면 됨.
# **가장 확실한 방법: train 데이터에 동일한 로직으로 스무딩 값을 다시 계산해서 비교**

# (약식 확인법) 인코딩된 값(Score)별로 학생 수의 평균을 봅니다.
# 만약 Score가 높은 구간(예: 0.9 이상)의 평균 학생 수가 매우 적다면 왜곡된 것입니다.

# df_all에서 인코딩된 컬럼과 원본 train을 인덱스로 매칭 (순서가 안 섞였다면)
comparison_df = pd.DataFrame({
    'student_count': train.groupby('school1')['completed'].transform('count'),
    'encoded_score': df_all.loc[df_all['dataset']=='train', 'school1_target_enc'].values,
    'completed': train['completed']
})

# 3. 시각화: 인코딩 점수(X) vs 학생 수(Y) 산점도
plt.figure(figsize=(10, 6))
sns.scatterplot(data=comparison_df, x='encoded_score', y='student_count', alpha=0.5)
plt.axhline(y=10, color='r', linestyle='--', label='학생수 10명 기준선') # 10명 미만 경계선
plt.title('Target Encoding Score vs Student Count')
plt.xlabel('Encoded Score (Smoothing applied)')
plt.ylabel('Student Count (Log scale recommended if skewed)')
plt.yscale('log') # 학생 수 차이가 크면 로그 스케일 적용
plt.legend()
plt.grid(True)
plt.show()

# 4. 수치로 확인: 점수가 상위 10%인 학교들의 평균 학생 수
top_10_percent_score = comparison_df['encoded_score'].quantile(0.9)
high_score_group = comparison_df[comparison_df['encoded_score'] >= top_10_percent_score]

print(f"상위 10% 점수({top_10_percent_score:.4f} 이상)를 받은 데이터들의 평균 학생 수:")
print(f"-> {high_score_group['student_count'].mean():.1f}명")

print("\n[진단 기준]")
print("- 점수가 높은데(X축 우측), 학생 수가 바닥(Y축 하단)에 깔린 점들이 많다면?")
print("-> 과적합(Overfitting) 가능성 매우 높음. m(스무딩 파라미터) 값을 키워야 함.")
# Out:
# 상위 10% 점수(0.3798 이상)를 받은 데이터들의 평균 학생 수:
# -> 21.1명
#
# [진단 기준]
# - 점수가 높은데(X축 우측), 학생 수가 바닥(Y축 하단)에 깔린 점들이 많다면?
# -> 과적합(Overfitting) 가능성 매우 높음. m(스무딩 파라미터) 값을 키워야 함.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from tqdm import tqdm
import pandas as pd
import numpy as np

def calculate_vif_filtered(df_input):
    """
    1. 모든 수치형 변수 VIF 계산
    2. 원-핫 인코딩된 변수 제외
    3. VIF 10 이상만 필터링
    """
    # 1. 수치형 데이터만 선택
    vif_data = df_input.select_dtypes(include=[np.number]).copy()
    vif_data = vif_data.astype(float)
    
    # 2. 원-핫 인코딩되었다고 판단되는 접두사(Prefix) 목록 정의
    # (이전 전처리 과정에서 get_dummies를 수행한 원본 컬럼명들)
    ohe_prefixes = [
        'class1_', 'job_', 'hope_for_group_', 'desired_career_path_', 'incumbents_lecture_type_', 
        'desired_job_except_data_', 'expected_domain_', 'what_to_gain_', 'incumbents_lecture_', 
        'incumbents_company_level_', 'inflow_route_', 'incumbents_lecture_scale_', 'whyBDA_', 
        'desired_certificate_', 'desired_job_', 'certificate_acquisition_', 'onedayclass_topic_', 
        'major_field_', 'major1_1_', 'major1_2_', 'class2_',
        'previous_class_6_', 'previous_class_7_', 'previous_class_8_'
    ]

    # 제외할 컬럼 식별
    # (컬럼명이 위 접두사 중 하나로 시작하면 제외)
    cols_to_exclude = [col for col in vif_data.columns if any(col.startswith(prefix) for prefix in ohe_prefixes)]
    
    # 3. 제외 대상이 아닌 '순수 수치형/이진 변수'만 남김
    target_cols = [col for col in vif_data.columns if col not in cols_to_exclude]
    
    # (주의) VIF 계산은 '제외된 변수'들을 아예 배제하고 계산할지, 
    # 아니면 계산은 다 하고 보여주는 것만 필터링할지 결정해야 함.
    # -> 다중공선성은 '전체 변수 간의 관계'이므로 계산은 '전체(vif_data)'로 하고, 출력만 필터링하는 것이 맞음.
    
    print(f"총 {len(vif_data.columns)}개 변수로 VIF 계산 후, 원-핫 인코딩 변수 제외하고 출력합니다.")
    print("-" * 60)
    
    vif_list = []
    
    # 전체 변수에 대해 계산 (시간 소요)
    for i in tqdm(range(len(vif_data.columns))):
        col_name = vif_data.columns[i]
        
        # 최적화: 출력 대상(target_cols)이 아니면 굳이 리스트에 담을 필요 없지만,
        # VIF 함수 특성상 i번째 컬럼을 y로 놓고 나머지를 X로 쓰기 때문에
        # target_cols에 속한 변수들의 VIF를 구하려면 전체 행렬이 필요함.
        
        # 여기서는 '출력 대상'인 경우에만 결과 리스트에 추가
        if col_name in target_cols:
            try:
                vif = variance_inflation_factor(vif_data.values, i)
                vif_list.append({'Feature': col_name, 'VIF': vif})
            except Exception as e:
                vif_list.append({'Feature': col_name, 'VIF': 99999})

    # 4. 데이터프레임 변환
    vif_df = pd.DataFrame(vif_list)
    
    # 5. VIF 10 이상 필터링
    vif_df_high = vif_df[vif_df['VIF'] >= 10].sort_values(by='VIF', ascending=False).reset_index(drop=True)
    
    return vif_df_high

# [실행부]
# 1. Train 데이터 준비
if 'dataset' in df_all.columns:
    X_vif_check = df_all[df_all['dataset'] == 'train'].drop(columns=['completed', 'dataset'])
else:
    X_vif_check = df_all.drop(columns=['completed']) if 'completed' in df_all.columns else df_all

# 2. 함수 호출
final_vif_result = calculate_vif_filtered(X_vif_check)

# 3. 결과 출력
pd.set_option('display.max_rows', None)
print("\n" + "="*60)
print(f"=== [필터링 결과] VIF ≥ 10 인 주요 변수 (OHE 제외) ===")
print("="*60)

if final_vif_result.empty:
    print("✅ VIF가 10 이상인 주요 변수가 없습니다. (다중공선성 문제 없음)")
else:
    print(final_vif_result)
    print("-" * 60)
    print("※ inf: 다른 변수들과 완벽한 선형 관계 (즉시 조치 필요)")
    print("※ 10 이상: 다중공선성 높음 (제거 고려)")

pd.reset_option('display.max_rows')
# Out:
# 총 181개 변수로 VIF 계산 후, 원-핫 인코딩 변수 제외하고 출력합니다.
# ------------------------------------------------------------
# 100%|██████████| 181/181 [00:00<00:00, 284.69it/s]
# ============================================================
# === [필터링 결과] VIF ≥ 10 인 주요 변수 (OHE 제외) ===
# ============================================================
#            Feature        VIF
# 0  re_registration        inf
# 1       major type  11.362634
# ------------------------------------------------------------
# ※ inf: 다른 변수들과 완벽한 선형 관계 (즉시 조치 필요)
# ※ 10 이상: 다중공선성 높음 (제거 고려)

# %%
# =========================================================
# [최종] 다중공선성 높은 변수 제거 (VIF > 10)
# =========================================================

# 1. 제거할 변수 목록 정의
cols_to_remove_vif = ['re_registration', 'major type']

# 2. 실제로 존재하는 변수만 골라내기 (에러 방지)
real_remove_cols = [col for col in cols_to_remove_vif if col in df_all.columns]

if len(real_remove_cols) > 0:
    print(f"🚀 VIF가 높은 변수 제거 시작: {real_remove_cols}")
    
    # 3. 변수 제거 수행
    df_all = df_all.drop(columns=real_remove_cols)
    
    print("✅ 제거 완료!")
    print(f"   - 제거된 컬럼: {real_remove_cols}")
    print(f"   - 현재 남은 컬럼 수: {df_all.shape[1]}")
else:
    print("⚠️ 제거할 변수가 데이터프레임에 존재하지 않습니다. 이미 삭제되었거나 이름을 확인해주세요.")

# 4. 최종 데이터 확인 (선택 사항)
print("-" * 50)
print(f"📊 최종 모델링용 데이터 크기: {df_all.shape}")
# Out:
# 🚀 VIF가 높은 변수 제거 시작: ['re_registration', 'major type']
# ✅ 제거 완료!
#    - 제거된 컬럼: ['re_registration', 'major type']
#    - 현재 남은 컬럼 수: 181
# --------------------------------------------------
# 📊 최종 모델링용 데이터 크기: (1562, 181)

# %% [markdown]
# # 모델 학습 및 예측

# %%
import os
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
from catboost import CatBoostClassifier
import optuna
from optuna.samplers import TPESampler

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# =========================================================
# 1. 데이터 준비 (전처리 완료된 df_all 사용)
# =========================================================

# (1) Train / Test 분리
# Test 데이터에는 타겟 변수(completed)가 없으므로 제외하고 분리
train_final = df_all[df_all['dataset'] == 'train'].drop(columns=['dataset'])
test_final = df_all[df_all['dataset'] == 'test'].drop(columns=['dataset', 'completed'])

# (2) X, y 정의
X = train_final.drop(columns=['completed'])
y = train_final['completed'].astype(int)

# (3) 컬럼 순서 및 개수 일치 확인 (필수)
X_test = test_final[X.columns] # Train과 동일한 순서로 정렬

print(f"📌 데이터 준비 완료")
print(f"   - Train X: {X.shape}, y: {y.shape}")
print(f"   - Test X: {X_test.shape}")
print("-" * 50)


# =========================================================
# 2. Optuna를 활용한 하이퍼파라미터 튜닝 함수
# =========================================================
def objective_xgb(trial):
    """XGBoost 하이퍼파라미터 튜닝"""
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10), # 불균형 대응
        'random_state': 42,
        'n_jobs': -1,
        'eval_metric': 'logloss' # F1 최적화를 위해 logloss 사용 (이진분류)
    }
    
    # 5-Fold Stratified CV
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    f1_scores = []
    
    for train_idx, val_idx in skf.split(X, y):
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        model = xgb.XGBClassifier(**params)
        model.fit(X_tr, y_tr, verbose=False)
        
        preds = model.predict(X_val)
        f1 = f1_score(y_val, preds, average='binary') # Binary F1
        f1_scores.append(f1)
        
    return np.mean(f1_scores)

def objective_cat(trial):
    """CatBoost 하이퍼파라미터 튜닝"""
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'depth': trial.suggest_int('depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'random_seed': 42,
        'verbose': 0,
        'allow_writing_files': False
    }
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    f1_scores = []
    
    for train_idx, val_idx in skf.split(X, y):
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        model = CatBoostClassifier(**params)
        model.fit(X_tr, y_tr)
        
        preds = model.predict(X_val)
        f1 = f1_score(y_val, preds, average='binary')
        f1_scores.append(f1)
        
    return np.mean(f1_scores)


# =========================================================
# 3. 튜닝 실행 (시간 관계상 N_TRIALS 조정 가능)
# =========================================================
N_TRIALS = 30 # (빠르게 테스트하려면 줄이세요)

print(f"🚀 [XGBoost] Optuna 튜닝 시작 ({N_TRIALS}회)...")
study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_xgb.optimize(objective_xgb, n_trials=N_TRIALS)
best_params_xgb = study_xgb.best_params
print(f"✅ XGB Best F1: {study_xgb.best_value:.4f}")

print(f"\n🚀 [CatBoost] Optuna 튜닝 시작 ({N_TRIALS}회)...")
study_cat = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_cat.optimize(objective_cat, n_trials=N_TRIALS)
best_params_cat = study_cat.best_params
print(f"✅ Cat Best F1: {study_cat.best_value:.4f}")


# =========================================================
# 4. 최종 모델 학습 및 앙상블 (Soft Voting)
# =========================================================
print("\n" + "="*50)
print("🚀 최종 모델 학습 및 예측 (Soft Voting)")
print("="*50)

# (1) 최적 파라미터로 전체 데이터 재학습
final_xgb = xgb.XGBClassifier(**best_params_xgb, random_state=42, n_jobs=-1)
final_cat = CatBoostClassifier(**best_params_cat, random_seed=42, verbose=0, allow_writing_files=False)

final_xgb.fit(X, y)
final_cat.fit(X, y)

# (2) Test 데이터에 대한 확률 예측
prob_xgb = final_xgb.predict_proba(X_test)[:, 1]
prob_cat = final_cat.predict_proba(X_test)[:, 1]

# (3) 앙상블 (단순 평균) - 가중치 조절 가능 (예: 0.6 * xgb + 0.4 * cat)
final_prob = (prob_xgb + prob_cat) / 2

# (4) 최종 클래스 결정 (Threshold 0.5)
final_pred = (final_prob >= 0.5).astype(int)

print("✅ 예측 완료!")


# =========================================================
# 5. Feature Importance & 상관계수 시각화
# =========================================================
# (1) Feature Importance (XGBoost 기준)
plt.figure(figsize=(10, 12))
importances = pd.Series(final_xgb.feature_importances_, index=X.columns)
top20 = importances.sort_values(ascending=False).head(20)
sns.barplot(x=top20.values, y=top20.index)
plt.title('Top 20 Feature Importance (XGBoost)')
plt.show()

# (2) 종속변수 상관계수 시각화 (Top 20)
# (이미 전처리된 X에 y를 붙여서 계산)
temp_df = X.copy()
temp_df['target'] = y
corr_series = temp_df.corr()['target'].drop('target').abs().sort_values(ascending=False).head(20)

plt.figure(figsize=(10, 8))
sns.barplot(x=corr_series.values, y=corr_series.index, palette='viridis')
plt.title('Top 20 Correlation with Target (Absolute Value)')
plt.show()


# =========================================================
# 6. 결과 파일 저장
# =========================================================
# (1) 경로 설정
submit_dir = "../submit"
if not os.path.exists(submit_dir):
    os.makedirs(submit_dir)

# (2) 파일명 생성 (hmw오늘날짜_점수)
# 점수는 CV에서 나온 최고 점수 평균을 사용하거나 000으로 표시
# 여기서는 XGB와 Cat의 CV 최고점수 평균을 파일명에 기재
avg_cv_score = (study_xgb.best_value + study_cat.best_value) / 2
today_str = datetime.datetime.now().strftime("%m%d")
file_name = f"hmw{today_str}_{avg_cv_score:.3f}.csv"
save_path = os.path.join(submit_dir, file_name)

# (3) submission 파일 생성
# sample_submission 로드 (경로 주의: 사용 환경에 맞게 수정 필요)
# 여기서는 첨부해주신 파일명 기준
try:
    sub = pd.read_csv("sample_submission.csv") # 같은 폴더에 있다고 가정
except FileNotFoundError:
    sub = pd.read_csv("../datasets/sample_submission.csv") # 상위 폴더 가정

# ID는 submission 파일의 ID 순서를 따름 (혹시 순서가 섞였을까봐 merge 사용 추천)
# 하지만 보통 순서가 같으므로 직접 대입
sub['completed'] = final_pred

# (4) 저장
sub.to_csv(save_path, index=False)

print(f"\n🎉 저장 완료: {save_path}")
print(sub.head())
# Out:
# [I 2026-02-16 23:21:39,462] A new study created in memory with name: no-name-e403f14d-eb4f-4d9c-b605-5295ec81fccb
# 📌 데이터 준비 완료
#    - Train X: (748, 179), y: (748,)
#    - Test X: (814, 179)
# --------------------------------------------------
# 🚀 [XGBoost] Optuna 튜닝 시작 (30회)...
# [I 2026-02-16 23:21:42,447] Trial 0 finished with value: 0.37871124073496965 and parameters: {'n_estimators': 437, 'max_depth': 10, 'learning_rate': 0.22227824312530747, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'gamma': 0.7799726016810132, 'reg_alpha': 0.5808361216819946, 'reg_lambda': 8.661761457749352, 'scale_pos_weight': 6.41003510568888}. Best is trial 0 with value: 0.37871124073496965.
# [I 2026-02-16 23:21:47,823] Trial 1 finished with value: 0.3916066333819628 and parameters: {'n_estimators': 737, 'max_depth': 3, 'learning_rate': 0.29127385712697834, 'subsample': 0.9329770563201687, 'colsample_bytree': 0.6849356442713105, 'gamma': 0.9091248360355031, 'reg_alpha': 1.8340450985343382, 'reg_lambda': 3.0424224295953772, 'scale_pos_weight': 5.72280788469014}. Best is trial 1 with value: 0.3916066333819628.
# [I 2026-02-16 23:21:51,460] Trial 2 finished with value: 0.35376709748226776 and parameters: {'n_estimators': 489, 'max_depth': 5, 'learning_rate': 0.18743733946949004, 'subsample': 0.6557975442608167, 'colsample_bytree': 0.7168578594140873, 'gamma': 1.8318092164684585, 'reg_alpha': 4.56069984217036, 'reg_lambda': 7.851759613930136, 'scale_pos_weight': 2.7970640394252375}. Best is trial 1 with value: 0.3916066333819628.
# [I 2026-02-16 23:21:57,283] Trial 3 finished with value: 0.439230958959251 and parameters: {'n_estimators': 563, 'max_depth': 7, 'learning_rate': 0.02347061968879934, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'gamma': 0.3252579649263976, 'reg_alpha': 9.488855372533333, 'reg_lambda': 9.656320330745594, 'scale_pos_weight': 8.275576133048151}. Best is trial 3 with value: 0.439230958959251.
# [I 2026-02-16 23:22:00,204] Trial 4 finished with value: 0.38074834931650897 and parameters: {'n_estimators': 374, 'max_depth': 3, 'learning_rate': 0.2084275776885255, 'subsample': 0.7760609974958406, 'colsample_bytree': 0.6488152939379115, 'gamma': 2.475884550556351, 'reg_alpha': 0.34388521115218396, 'reg_lambda': 9.093204020787821, 'scale_pos_weight': 3.3290198344001523}. Best is trial 3 with value: 0.439230958959251.
# [I 2026-02-16 23:22:05,159] Trial 5 finished with value: 0.44731978573951564 and parameters: {'n_estimators': 696, 'max_depth': 5, 'learning_rate': 0.16081972614156514, 'subsample': 0.8186841117373118, 'colsample_bytree': 0.6739417822102108, 'gamma': 4.847923138822793, 'reg_alpha': 7.7513282336111455, 'reg_lambda': 9.394989415641891, 'scale_pos_weight': 9.053446153848839}. Best is trial 5 with value: 0.44731978573951564.
# [I 2026-02-16 23:22:11,156] Trial 6 finished with value: 0.42539200405657596 and parameters: {'n_estimators': 638, 'max_depth': 10, 'learning_rate': 0.03566282559505665, 'subsample': 0.6783931449676581, 'colsample_bytree': 0.6180909155642152, 'gamma': 1.6266516538163218, 'reg_alpha': 3.8867728968948203, 'reg_lambda': 2.713490317738959, 'scale_pos_weight': 8.458637582367365}. Best is trial 5 with value: 0.44731978573951564.
# [I 2026-02-16 23:22:14,606] Trial 7 finished with value: 0.3711764366470147 and parameters: {'n_estimators': 421, 'max_depth': 5, 'learning_rate': 0.16738186411589207, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'gamma': 0.3727532183988541, 'reg_alpha': 9.868869366005173, 'reg_lambda': 7.722447692966574, 'scale_pos_weight': 2.7884411338075514}. Best is trial 5 with value: 0.44731978573951564.
# [I 2026-02-16 23:22:15,932] Trial 8 finished with value: 0.38547354075901274 and parameters: {'n_estimators': 104, 'max_depth': 9, 'learning_rate': 0.21498862971580895, 'subsample': 0.8916028672163949, 'colsample_bytree': 0.9085081386743783, 'gamma': 0.3702232586704518, 'reg_alpha': 3.5846572854427263, 'reg_lambda': 1.1586905952512971, 'scale_pos_weight': 8.767930832880342}. Best is trial 5 with value: 0.44731978573951564.
# [I 2026-02-16 23:22:20,970] Trial 9 finished with value: 0.43886826734680495 and parameters: {'n_estimators': 661, 'max_depth': 5, 'learning_rate': 0.028431921582946856, 'subsample': 0.7243929286862649, 'colsample_bytree': 0.7300733288106989, 'gamma': 3.64803089169032, 'reg_alpha': 6.3755747135521315, 'reg_lambda': 8.872127425763265, 'scale_pos_weight': 5.249934326457543}. Best is trial 5 with value: 0.44731978573951564.
# [I 2026-02-16 23:22:27,559] Trial 10 finished with value: 0.45447424926665725 and parameters: {'n_estimators': 967, 'max_depth': 7, 'learning_rate': 0.10370672690566779, 'subsample': 0.9729161367647149, 'colsample_bytree': 0.8112687136962431, 'gamma': 4.538323976412588, 'reg_alpha': 7.303668952070094, 'reg_lambda': 6.062890283015679, 'scale_pos_weight': 9.729064085503467}. Best is trial 10 with value: 0.45447424926665725.
# [I 2026-02-16 23:22:34,671] Trial 11 finished with value: 0.45232777690552484 and parameters: {'n_estimators': 998, 'max_depth': 7, 'learning_rate': 0.10529401479292866, 'subsample': 0.9826791585185581, 'colsample_bytree': 0.8142497056141959, 'gamma': 4.982635852231621, 'reg_alpha': 7.048659529327457, 'reg_lambda': 5.844044664797912, 'scale_pos_weight': 9.99027383597975}. Best is trial 10 with value: 0.45447424926665725.
# [I 2026-02-16 23:22:43,131] Trial 12 finished with value: 0.455917740636327 and parameters: {'n_estimators': 971, 'max_depth': 7, 'learning_rate': 0.09064987184786105, 'subsample': 0.9995045229260103, 'colsample_bytree': 0.8382475684166883, 'gamma': 4.789035353260928, 'reg_alpha': 7.0116259539376, 'reg_lambda': 5.29448263772488, 'scale_pos_weight': 9.928342356903505}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:22:51,854] Trial 13 finished with value: 0.45377129107699055 and parameters: {'n_estimators': 997, 'max_depth': 8, 'learning_rate': 0.0950446527991815, 'subsample': 0.9997449754566203, 'colsample_bytree': 0.8293619883805838, 'gamma': 3.970125069488835, 'reg_alpha': 8.269833696406016, 'reg_lambda': 5.594255606534141, 'scale_pos_weight': 7.169541473160408}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:00,779] Trial 14 finished with value: 0.4375540757408416 and parameters: {'n_estimators': 833, 'max_depth': 8, 'learning_rate': 0.07674398500697605, 'subsample': 0.9406917231395525, 'colsample_bytree': 0.9985782486270702, 'gamma': 3.965655313990263, 'reg_alpha': 5.587985830433143, 'reg_lambda': 3.99980699383715, 'scale_pos_weight': 4.483824595418893}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:08,878] Trial 15 finished with value: 0.43609319798300505 and parameters: {'n_estimators': 860, 'max_depth': 6, 'learning_rate': 0.12082140328795783, 'subsample': 0.904239012473028, 'colsample_bytree': 0.7648437305206914, 'gamma': 3.270356634632334, 'reg_alpha': 8.494375359723527, 'reg_lambda': 6.705451426048862, 'scale_pos_weight': 9.795398190355701}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:16,586] Trial 16 finished with value: 0.0 and parameters: {'n_estimators': 887, 'max_depth': 8, 'learning_rate': 0.06634604434899452, 'subsample': 0.9508114971577906, 'colsample_bytree': 0.864277554783387, 'gamma': 4.4388723541807105, 'reg_alpha': 6.134123924438912, 'reg_lambda': 4.529004908131039, 'scale_pos_weight': 1.1186129294283118}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:19,320] Trial 17 finished with value: 0.4361759156728935 and parameters: {'n_estimators': 292, 'max_depth': 6, 'learning_rate': 0.1306693447495726, 'subsample': 0.8782129086835808, 'colsample_bytree': 0.8758697700847069, 'gamma': 2.9304031857025086, 'reg_alpha': 7.292872054446186, 'reg_lambda': 6.827387534157062, 'scale_pos_weight': 7.041132706154968}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:26,589] Trial 18 finished with value: 0.42948420518894725 and parameters: {'n_estimators': 778, 'max_depth': 9, 'learning_rate': 0.06315855318608198, 'subsample': 0.6015688184486825, 'colsample_bytree': 0.7776811511523464, 'gamma': 4.458137059033803, 'reg_alpha': 4.833184804019667, 'reg_lambda': 0.9017405294742789, 'scale_pos_weight': 7.9968166824982925}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:34,814] Trial 19 finished with value: 0.4294610154600532 and parameters: {'n_estimators': 933, 'max_depth': 7, 'learning_rate': 0.13650281965460254, 'subsample': 0.7727431143998708, 'colsample_bytree': 0.9751814903889434, 'gamma': 2.5694057876825567, 'reg_alpha': 8.711746125390345, 'reg_lambda': 3.0655753326015205, 'scale_pos_weight': 9.36817893461327}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:41,466] Trial 20 finished with value: 0.4401220037167077 and parameters: {'n_estimators': 783, 'max_depth': 4, 'learning_rate': 0.2591953765982367, 'subsample': 0.9659918655267106, 'colsample_bytree': 0.8496018535458107, 'gamma': 4.357695247097669, 'reg_alpha': 2.5997423016857732, 'reg_lambda': 5.197202893289965, 'scale_pos_weight': 7.450471687608263}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:49,653] Trial 21 finished with value: 0.4514525177039369 and parameters: {'n_estimators': 975, 'max_depth': 8, 'learning_rate': 0.09895321187662313, 'subsample': 0.9961338495210137, 'colsample_bytree': 0.8230117605881178, 'gamma': 3.8568224233447324, 'reg_alpha': 8.762833287708604, 'reg_lambda': 5.916559456133074, 'scale_pos_weight': 7.258043613845105}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:23:57,605] Trial 22 finished with value: 0.4490607101947308 and parameters: {'n_estimators': 907, 'max_depth': 9, 'learning_rate': 0.0839194721578663, 'subsample': 0.9977283619310188, 'colsample_bytree': 0.7799153926350552, 'gamma': 4.1338707874439695, 'reg_alpha': 7.679738501150653, 'reg_lambda': 5.4328419921351925, 'scale_pos_weight': 9.176875254532046}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:06,453] Trial 23 finished with value: 0.42870037454214216 and parameters: {'n_estimators': 980, 'max_depth': 8, 'learning_rate': 0.05652232452868734, 'subsample': 0.9191446880463602, 'colsample_bytree': 0.9122255244175714, 'gamma': 3.451042005753745, 'reg_alpha': 6.534336288045325, 'reg_lambda': 6.9319562030540025, 'scale_pos_weight': 6.351567921667675}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:13,677] Trial 24 finished with value: 0.44973098011954205 and parameters: {'n_estimators': 821, 'max_depth': 6, 'learning_rate': 0.10389159817393179, 'subsample': 0.963640914754891, 'colsample_bytree': 0.8402842742389768, 'gamma': 4.583318745258725, 'reg_alpha': 8.116826348549703, 'reg_lambda': 4.345480698209202, 'scale_pos_weight': 9.82149864647014}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:21,526] Trial 25 finished with value: 0.4425420395312366 and parameters: {'n_estimators': 919, 'max_depth': 7, 'learning_rate': 0.14778162920127144, 'subsample': 0.8716844621710427, 'colsample_bytree': 0.7346782301763461, 'gamma': 4.998502176756443, 'reg_alpha': 5.92949157162806, 'reg_lambda': 6.2065348601054895, 'scale_pos_weight': 7.80576476398002}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:26,681] Trial 26 finished with value: 0.44878977288303706 and parameters: {'n_estimators': 588, 'max_depth': 8, 'learning_rate': 0.04849903790951401, 'subsample': 0.9640716878750103, 'colsample_bytree': 0.8004911066267439, 'gamma': 3.157466086592968, 'reg_alpha': 9.278868110457294, 'reg_lambda': 3.6753990227448665, 'scale_pos_weight': 8.707664743084898}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:34,468] Trial 27 finished with value: 0.445945638950482 and parameters: {'n_estimators': 994, 'max_depth': 6, 'learning_rate': 0.0914211906252423, 'subsample': 0.9258652746820958, 'colsample_bytree': 0.882647722968997, 'gamma': 4.10171909203088, 'reg_alpha': 7.08093189355845, 'reg_lambda': 1.9821992391487555, 'scale_pos_weight': 6.485441231867458}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:41,447] Trial 28 finished with value: 0.4459411424775297 and parameters: {'n_estimators': 857, 'max_depth': 9, 'learning_rate': 0.011172191233198472, 'subsample': 0.9829110763712434, 'colsample_bytree': 0.9354246023179204, 'gamma': 4.707818057460739, 'reg_alpha': 5.480669620997347, 'reg_lambda': 4.932622962692587, 'scale_pos_weight': 4.441896577193764}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:47,646] Trial 29 finished with value: 0.4441566388435624 and parameters: {'n_estimators': 741, 'max_depth': 10, 'learning_rate': 0.11309658364604411, 'subsample': 0.9959008627960059, 'colsample_bytree': 0.7556439235001488, 'gamma': 3.729507692230249, 'reg_alpha': 6.700542667917324, 'reg_lambda': 7.771540844584965, 'scale_pos_weight': 6.725946177626014}. Best is trial 12 with value: 0.455917740636327.
# [I 2026-02-16 23:24:47,650] A new study created in memory with name: no-name-d53444e4-7cf8-4635-8247-8e9c8a146fd4
# ✅ XGB Best F1: 0.4559
#
# 🚀 [CatBoost] Optuna 튜닝 시작 (30회)...
# [I 2026-02-16 23:25:33,208] Trial 0 finished with value: 0.16269550549949274 and parameters: {'iterations': 437, 'depth': 10, 'learning_rate': 0.22227824312530747, 'l2_leaf_reg': 6.387926357773329, 'border_count': 66, 'scale_pos_weight': 2.403950683025824}. Best is trial 0 with value: 0.16269550549949274.
# [I 2026-02-16 23:25:43,517] Trial 1 finished with value: 0.34030775331031954 and parameters: {'iterations': 152, 'depth': 9, 'learning_rate': 0.18432335340553055, 'l2_leaf_reg': 7.372653200164409, 'border_count': 36, 'scale_pos_weight': 9.72918866945795}. Best is trial 1 with value: 0.34030775331031954.
# [I 2026-02-16 23:25:52,266] Trial 2 finished with value: 0.3629872043665147 and parameters: {'iterations': 850, 'depth': 4, 'learning_rate': 0.06272924049005918, 'l2_leaf_reg': 2.650640588680904, 'border_count': 100, 'scale_pos_weight': 5.72280788469014}. Best is trial 2 with value: 0.3629872043665147.
# [I 2026-02-16 23:25:58,611] Trial 3 finished with value: 0.27363670562864467 and parameters: {'iterations': 489, 'depth': 5, 'learning_rate': 0.18743733946949004, 'l2_leaf_reg': 2.2554447458683766, 'border_count': 97, 'scale_pos_weight': 4.297256589643226}. Best is trial 2 with value: 0.3629872043665147.
# [I 2026-02-16 23:26:37,154] Trial 4 finished with value: 0.09836019657270897 and parameters: {'iterations': 510, 'depth': 9, 'learning_rate': 0.06790539682592432, 'l2_leaf_reg': 5.628109945722504, 'border_count': 164, 'scale_pos_weight': 1.4180537144799796}. Best is trial 2 with value: 0.3629872043665147.
# [I 2026-02-16 23:26:44,042] Trial 5 finished with value: 0.41435665409858957 and parameters: {'iterations': 647, 'depth': 4, 'learning_rate': 0.02886496196573106, 'l2_leaf_reg': 9.539969835279999, 'border_count': 248, 'scale_pos_weight': 8.275576133048151}. Best is trial 5 with value: 0.41435665409858957.
# [I 2026-02-16 23:26:47,171] Trial 6 finished with value: 0.3617449489812813 and parameters: {'iterations': 374, 'depth': 3, 'learning_rate': 0.2084275776885255, 'l2_leaf_reg': 4.961372443656412, 'border_count': 59, 'scale_pos_weight': 5.456592191001432}. Best is trial 5 with value: 0.41435665409858957.
# [I 2026-02-16 23:27:03,612] Trial 7 finished with value: 0.37370626921588984 and parameters: {'iterations': 130, 'depth': 10, 'learning_rate': 0.0850461946640049, 'l2_leaf_reg': 6.962700559185838, 'border_count': 101, 'scale_pos_weight': 5.680612190600297}. Best is trial 5 with value: 0.41435665409858957.
# [I 2026-02-16 23:27:09,947] Trial 8 finished with value: 0.3264908760665709 and parameters: {'iterations': 592, 'depth': 4, 'learning_rate': 0.291179542051722, 'l2_leaf_reg': 7.976195410250031, 'border_count': 242, 'scale_pos_weight': 9.053446153848839}. Best is trial 5 with value: 0.41435665409858957.
# [I 2026-02-16 23:28:28,526] Trial 9 finished with value: 0.20740957205013313 and parameters: {'iterations': 638, 'depth': 10, 'learning_rate': 0.03566282559505665, 'l2_leaf_reg': 2.763845761772307, 'border_count': 42, 'scale_pos_weight': 3.927972976869379}. Best is trial 5 with value: 0.41435665409858957.
# [I 2026-02-16 23:28:58,789] Trial 10 finished with value: 0.3151182033096927 and parameters: {'iterations': 960, 'depth': 7, 'learning_rate': 0.11693134408911823, 'l2_leaf_reg': 9.596303461374518, 'border_count': 252, 'scale_pos_weight': 8.04139542898136}. Best is trial 5 with value: 0.41435665409858957.
# [I 2026-02-16 23:29:02,515] Trial 11 finished with value: 0.45930649661219614 and parameters: {'iterations': 114, 'depth': 7, 'learning_rate': 0.016453219271359707, 'l2_leaf_reg': 9.922174139832322, 'border_count': 179, 'scale_pos_weight': 7.27440308506085}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:29:24,777] Trial 12 finished with value: 0.4247122107183202 and parameters: {'iterations': 735, 'depth': 7, 'learning_rate': 0.015050938331240295, 'l2_leaf_reg': 9.728743764088852, 'border_count': 200, 'scale_pos_weight': 7.515334316056558}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:29:48,828] Trial 13 finished with value: 0.3018324675780216 and parameters: {'iterations': 786, 'depth': 7, 'learning_rate': 0.12364147757947011, 'l2_leaf_reg': 9.99401064690432, 'border_count': 193, 'scale_pos_weight': 7.114993077892391}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:29:55,050] Trial 14 finished with value: 0.45930649661219614 and parameters: {'iterations': 290, 'depth': 6, 'learning_rate': 0.010938946881741022, 'l2_leaf_reg': 8.865741344904174, 'border_count': 182, 'scale_pos_weight': 7.005210494307714}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:00,955] Trial 15 finished with value: 0.3439569130013903 and parameters: {'iterations': 278, 'depth': 6, 'learning_rate': 0.11156659218962256, 'l2_leaf_reg': 8.32604157646504, 'border_count': 147, 'scale_pos_weight': 6.80206316741277}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:06,179] Trial 16 finished with value: 0.45354283356439273 and parameters: {'iterations': 248, 'depth': 6, 'learning_rate': 0.013964171555637383, 'l2_leaf_reg': 4.246678190897125, 'border_count': 194, 'scale_pos_weight': 6.496941703053112}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:19,592] Trial 17 finished with value: 0.31268290814795324 and parameters: {'iterations': 266, 'depth': 8, 'learning_rate': 0.05188947911868451, 'l2_leaf_reg': 8.616674778575357, 'border_count': 218, 'scale_pos_weight': 3.591183695185578}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:21,724] Trial 18 finished with value: 0.4497727741170447 and parameters: {'iterations': 109, 'depth': 5, 'learning_rate': 0.08945168577706299, 'l2_leaf_reg': 8.728417439246778, 'border_count': 168, 'scale_pos_weight': 8.654323838775236}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:38,237] Trial 19 finished with value: 0.25767031307395444 and parameters: {'iterations': 342, 'depth': 8, 'learning_rate': 0.15056757426396256, 'l2_leaf_reg': 7.503233465822975, 'border_count': 133, 'scale_pos_weight': 4.877672977994635}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:42,930] Trial 20 finished with value: 0.2885624357145766 and parameters: {'iterations': 213, 'depth': 6, 'learning_rate': 0.27106230266707126, 'l2_leaf_reg': 6.3967675997766165, 'border_count': 129, 'scale_pos_weight': 6.275466692622508}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:47,601] Trial 21 finished with value: 0.45389090682477784 and parameters: {'iterations': 211, 'depth': 6, 'learning_rate': 0.014934538538208456, 'l2_leaf_reg': 3.997969844272749, 'border_count': 185, 'scale_pos_weight': 6.5627720384196895}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:30:53,839] Trial 22 finished with value: 0.4011528624827857 and parameters: {'iterations': 364, 'depth': 5, 'learning_rate': 0.04128269744323686, 'l2_leaf_reg': 3.8042022386311753, 'border_count': 167, 'scale_pos_weight': 7.66758916229635}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:03,171] Trial 23 finished with value: 0.44778207021345223 and parameters: {'iterations': 199, 'depth': 8, 'learning_rate': 0.013086794518227956, 'l2_leaf_reg': 1.1044868292723429, 'border_count': 216, 'scale_pos_weight': 7.060120341889913}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:09,570] Trial 24 finished with value: 0.3718865129342573 and parameters: {'iterations': 300, 'depth': 6, 'learning_rate': 0.07935829938882087, 'l2_leaf_reg': 4.01271617884764, 'border_count': 177, 'scale_pos_weight': 9.418542515928165}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:14,965] Trial 25 finished with value: 0.4473207970537304 and parameters: {'iterations': 176, 'depth': 7, 'learning_rate': 0.04093999211013024, 'l2_leaf_reg': 8.991163980470084, 'border_count': 225, 'scale_pos_weight': 6.181060471478382}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:21,623] Trial 26 finished with value: 0.3410159716060337 and parameters: {'iterations': 432, 'depth': 5, 'learning_rate': 0.06147749681348369, 'l2_leaf_reg': 5.971566650670963, 'border_count': 185, 'scale_pos_weight': 4.690471720434054}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:24,132] Trial 27 finished with value: 0.43364127945717074 and parameters: {'iterations': 111, 'depth': 6, 'learning_rate': 0.09976907151864323, 'l2_leaf_reg': 5.227788060015854, 'border_count': 150, 'scale_pos_weight': 8.566853073387936}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:34,018] Trial 28 finished with value: 0.3330992067245168 and parameters: {'iterations': 205, 'depth': 8, 'learning_rate': 0.13629258043835282, 'l2_leaf_reg': 9.061205344842529, 'border_count': 208, 'scale_pos_weight': 7.719856068667409}. Best is trial 11 with value: 0.45930649661219614.
# [I 2026-02-16 23:31:48,552] Trial 29 finished with value: 0.23025048687849017 and parameters: {'iterations': 438, 'depth': 7, 'learning_rate': 0.2458910626921071, 'l2_leaf_reg': 3.3472091980658902, 'border_count': 121, 'scale_pos_weight': 3.387677521686183}. Best is trial 11 with value: 0.45930649661219614.
# ✅ Cat Best F1: 0.4593
#
# ==================================================
# 🚀 최종 모델 학습 및 예측 (Soft Voting)
# ==================================================
# ✅ 예측 완료!
# 🎉 저장 완료: ../submit\hmw0216_0.458.csv
#          ID  completed
# 0  TEST_000          1
# 1  TEST_001          1
# 2  TEST_002          1
# 3  TEST_003          1
# 4  TEST_004          1
